# %% [markdown]
# # Explicit Factor Model [Zhang et al]

# %%
import pickle
import time
from collections import deque

from sklearn.utils import shuffle
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_auc_score

import numpy as np
import networkx as nx

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
from multiprocessing import Pool

from scipy.sparse import lil_matrix, csr_matrix, csc_matrix
from scipy.sparse import vstack

import sys

torch.manual_seed(1)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'cpu'

# %% [markdown]
# ## ネットワーク読み込み, implicit feed back, user/item辞書

# %%
# ネットワーク
KG = pickle.load(open('../knowledge_graph/trip_ad/trip_ad_graph.pickle', 'rb'))
print(len(KG.edges()))
print(len(KG.nodes()))
# Out:
# 30191
# 8074

# %%
# implicit feedback
edges = list(KG.edges())
# implicit feedback のedgeを格納
implicit_feedback = []

for e in edges:
    if e[0][0:2] == 'u_':
        implicit_feedback.append(e)
    elif e[1][0:2] == 'u_':
        implicit_feedback.append(e)
        
print(len(implicit_feedback))
# Out:
# 23029

# %%
# user item dictionary
user2idx = {}
item2idx = {}
user2idx2 = {}
item2idx2 = {}
user_list = []
item_list = []
user_list2 = []
item_list2 = []

for f in implicit_feedback:
    if f[0][0:2] == 'u_':
        user = f[0]
        item = f[1]
    else:
        user = f[1]
        item = f[0]
        
    if user[2:] not in user2idx:
        user2idx[user[2:]] = len(user2idx)
        user2idx2[user] = len(user2idx)
    if item[2:] not in item2idx:
        item2idx[item[2:]] = len(item2idx)
        item2idx2[item] = len(item2idx)
        
        
user_list = list(user2idx)
item_list = list(item2idx)
user_list2 = list(user2idx2)
item_list2 = list(item2idx2)

print('user :{}'.format(len(user_list)))
print('item :{}'.format(len(item_list)))
# Out:
# user :6134
# item :1763

# %%
with open('user2idx.pickle', 'wb') as f:
    pickle.dump(user2idx, f)
with open('item2idx.pickle', 'wb') as f:
    pickle.dump(item2idx, f)

# %% [markdown]
# ## aspectの行列

# %%
user_aspect_dict = pickle.load(open('../trip_ad_test/aspect_word_feature/user_aspect_feat.pickle', 'rb'))
item_aspect_dict = pickle.load(open('../trip_ad_test/aspect_word_feature/item_aspect_feat.pickle', 'rb'))

# %%
user_aspect_dict2 = {}
for k in user_aspect_dict:
    user_aspect_dict2[user2idx[k]] = user_aspect_dict[k]
    
item_aspect_dict2 = {}
for k in item_aspect_dict:
    item_aspect_dict2[item2idx[k]] = item_aspect_dict[k]

# %%
with open('user_aspect_dict.pickle', 'wb') as f:
    pickle.dump(user_aspect_dict2, f)
    
with open('item_aspect_dict.pickle', 'wb') as f:
    pickle.dump(item_aspect_dict2, f)

# %%
print(len(item2idx))
print(len(item_aspect_dict))
print(len(item_aspect_dict2))

print(len(user2idx))
print(len(user_aspect_dict2))
print(len(user_aspect_dict))
# Out:
# 1763
# 1763
# 1763
# 6134
# 6134
# 6134

# %% [markdown]
# ## Negaデータづくり

# %%
nega_data = []

while len(nega_data) != len(implicit_feedback):
    idx_u = np.random.randint(0, len(user_list))
    idx_i = np.random.randint(0, len(item_list))

    if (user_list[idx_u], item_list[idx_i]) in implicit_feedback:
        continue
    else:
        nega_data.append((user_list2[idx_u], item_list2[idx_i]))

# %% [markdown]
# ## NegaとPosi(Implicit Feedback)の中身を全てIDにする

# %%
def swap_u_i(datas):
    idx_list = []
    for i in range(len(datas)):
        datas[i] = list(datas[i])
        if datas[i][0][0] == 'u':
            
            tmp = datas[i][0]
            datas[i][0] = datas[i][1]
            datas[i][1] = tmp 
        
        idx_list.append([item2idx[datas[i][0][2:]], user2idx[datas[i][1][2:]]])
            
    return idx_list

# %%
posi_data = np.array(swap_u_i(implicit_feedback))
nega_data = np.array(swap_u_i(nega_data))

# %%
# Out:
# [['i_77055', 'u_Cubzter'],
#  ['i_89096', 'u_Cubzter'],
#  ['i_111969', 'u_Cubzter'],
#  ['i_262330', 'u_Cubzter'],
#  ['i_156511', 'u_chekhov61'],
#  ['i_149920', 'u_chekhov61'],
#  ['i_198109', 'u_chekhov61'],
#  ['i_81170', 'u_chekhov61'],
#  ['i_156511', 'u_Michparis'],
#  ['i_268240', 'u_Michparis'],
#  ['i_86969', 'u_Michparis'],
#  ['i_197792', 'u_travel_mad83'],
#  ['i_232493', 'u_travel_mad83'],
#  ['i_528508', 'u_travel_mad83'],
#  ['i_197792', 'u_Bearfoot'],
#  ['i_197792', 'u_JRGreen'],
#  ['i_188937', 'u_Bearfoot'],
#  ['i_287670', 'u_Bearfoot'],
#  ['i_81192', 'u_JRGreen'],
#  ['i_76061', 'u_JRGreen'],
#  ['i_81363', 'u_JRGreen'],
#  ['i_197794', 'u_ebarav'],
#  ['i_254575', 'u_ebarav'],
#  ['i_282590', 'u_ebarav'],
#  ['i_197794', 'u_connectingvodka'],
#  ['i_197794', 'u_beechmi'],
#  ['i_197794', 'u_westashleyguy'],
#  ['i_237582', 'u_connectingvodka'],
#  ['i_506652', 'u_connectingvodka'],
#  ['i_199397', 'u_beechmi'],
#  ['i_305810', 'u_beechmi'],
#  ['i_230572', 'u_beechmi'],
#  ['i_152473', 'u_beechmi'],
#  ['i_111974', 'u_beechmi'],
#  ['i_150849', 'u_westashleyguy'],
#  ['i_152474', 'u_westashleyguy'],
#  ['i_301028', 'u_cybertraveler14'],
#  ['i_573158', 'u_cybertraveler14'],
#  ['i_301028', 'u_Tokyodude'],
#  ['i_301028', 'u_JohnsonFive'],
#  ['i_301028', 'u_dbasha'],
#  ['i_301028', 'u_銇炽倱銇°們銈?> 銇炽倱銇°們銈?</a> </div>'],
#  ['i_285755', 'u_Tokyodude'],
#  ['i_302249', 'u_Tokyodude'],
#  ['i_100505', 'u_JohnsonFive'],
#  ['i_301581', 'u_JohnsonFive'],
#  ['i_302139', 'u_dbasha'],
#  ['i_301787', 'u_dbasha'],
#  ['i_309124', 'u_dbasha'],
#  ['i_256544', 'u_dbasha'],
#  ['i_255650', 'u_dbasha'],
#  ['i_76442', 'u_dbasha'],
#  ['i_306173', 'u_dbasha'],
#  ['i_300154', 'u_銇炽倱銇°們銈?> 銇炽倱銇°們銈?</a> </div>'],
#  ['i_305854', 'u_銇炽倱銇°們銈?> 銇炽倱銇°們銈?</a> </div>'],
#  ['i_199355', 'u_danimerolone'],
#  ['i_234752', 'u_danimerolone'],
#  ['i_503002', 'u_danimerolone'],
#  ['i_89155', 'u_LouisianaFireball'],
#  ['i_93051', 'u_LouisianaFireball'],
#  ['i_284441', 'u_LouisianaFireball'],
#  ['i_258626', 'u_LouisianaFireball'],
#  ['i_89118', 'u_LouisianaFireball'],
#  ['i_93034', 'u_LouisianaFireball'],
#  ['i_89155', 'u_Sublimebrad'],
#  ['i_89155', 'u_Mytravelreview68'],
#  ['i_89155', 'u_chrisvnardmore'],
#  ['i_89155', 'u_nola_girl76'],
#  ['i_89155', 'u_ChicagoJeffrey'],
#  ['i_89155', 'u_WorldTraveller-Bajan'],
#  ['i_89155', 'u_suzchsh'],
#  ['i_89155', 'u_kruzlady'],
#  ['i_89155', 'u_DFGA'],
#  ['i_89155', 'u_tooltimeterry'],
#  ['i_89155', 'u_lapochka'],
#  ['i_223408', 'u_Sublimebrad'],
#  ['i_93507', 'u_Sublimebrad'],
#  ['i_223129', 'u_Sublimebrad'],
#  ['i_223120', 'u_Sublimebrad'],
#  ['i_93047', 'u_Mytravelreview68'],
#  ['i_89096', 'u_Mytravelreview68'],
#  ['i_286358', 'u_Mytravelreview68'],
#  ['i_109412', 'u_chrisvnardmore'],
#  ['i_217378', 'u_chrisvnardmore'],
#  ['i_309180', 'u_chrisvnardmore'],
#  ['i_249682', 'u_nola_girl76'],
#  ['i_93459', 'u_nola_girl76'],
#  ['i_93047', 'u_nola_girl76'],
#  ['i_93164', 'u_nola_girl76'],
#  ['i_597573', 'u_ChicagoJeffrey'],
#  ['i_256733', 'u_ChicagoJeffrey'],
#  ['i_224221', 'u_WorldTraveller-Bajan'],
#  ['i_85193', 'u_WorldTraveller-Bajan'],
#  ['i_304546', 'u_WorldTraveller-Bajan'],
#  ['i_85204', 'u_WorldTraveller-Bajan'],
#  ['i_120432', 'u_suzchsh'],
#  ['i_120988', 'u_suzchsh'],
#  ['i_224875', 'u_suzchsh'],
#  ['i_217704', 'u_kruzlady'],
#  ['i_255674', 'u_kruzlady'],
#  ['i_85193', 'u_DFGA'],
#  ['i_256733', 'u_DFGA'],
#  ['i_111978', 'u_tooltimeterry'],
#  ['i_93247', 'u_tooltimeterry'],
#  ['i_149920', 'u_lapochka'],
#  ['i_149921', 'u_lapochka'],
#  ['i_614361', 'u_Travellotte'],
#  ['i_296916', 'u_Travellotte'],
#  ['i_236350', 'u_Travellotte'],
#  ['i_614361', 'u_Ontario_Sun_lovers'],
#  ['i_614361', 'u_Travelminx'],
#  ['i_614361', 'u_Spiderman32'],
#  ['i_614361', 'u_caviargal'],
#  ['i_614361', 'u_UkCarlos'],
#  ['i_614361', 'u_Shakers_7'],
#  ['i_614361', 'u_ShropshireSkiers'],
#  ['i_614361', 'u_DADeetz'],
#  ['i_614361', 'u_Steve_Med'],
#  ['i_614361', 'u_guy999'],
#  ['i_81192', 'u_Ontario_Sun_lovers'],
#  ['i_278586', 'u_Ontario_Sun_lovers'],
#  ['i_228728', 'u_Travelminx'],
#  ['i_198085', 'u_Travelminx'],
#  ['i_100562', 'u_Spiderman32'],
#  ['i_609760', 'u_Spiderman32'],
#  ['i_286582', 'u_caviargal'],
#  ['i_229032', 'u_caviargal'],
#  ['i_290014', 'u_caviargal'],
#  ['i_87016', 'u_UkCarlos'],
#  ['i_302249', 'u_UkCarlos'],
#  ['i_302109', 'u_UkCarlos'],
#  ['i_192064', 'u_Shakers_7'],
#  ['i_80983', 'u_Shakers_7'],
#  ['i_76083', 'u_Shakers_7'],
#  ['i_301583', 'u_ShropshireSkiers'],
#  ['i_256639', 'u_ShropshireSkiers'],
#  ['i_80083', 'u_ShropshireSkiers'],
#  ['i_202988', 'u_DADeetz'],
#  ['i_455460', 'u_DADeetz'],
#  ['i_202982', 'u_Steve_Med'],
#  ['i_208454', 'u_Steve_Med'],
#  ['i_275856', 'u_guy999'],
#  ['i_114942', 'u_guy999'],
#  ['i_208454', 'u_guy999'],
#  ['i_321151', 'u_suzyjacuzzi'],
#  ['i_126260', 'u_suzyjacuzzi'],
#  ['i_148043', 'u_suzyjacuzzi'],
#  ['i_321151', 'u_alzo'],
#  ['i_321151', 'u_Traveller from UK'],
#  ['i_321151', 'u_Kendo3'],
#  ['i_321151', 'u_Fitzy2'],
#  ['i_321151', 'u_Craigtown'],
#  ['i_321151', 'u_Ben_melb'],
#  ['i_321151', 'u_Brian_NVA'],
#  ['i_321151', 'u_Globe24/7'],
#  ['i_321151', 'u_jetlagged7'],
#  ['i_321151', 'u_janiel'],
#  ['i_321151', 'u_Tonyeng'],
#  ['i_321151', 'u_Dana_SF'],
#  ['i_321151', 'u_Baltimoron'],
#  ['i_321151', 'u_kenyonmartin2003'],
#  ['i_321151', 'u_ian_ok'],
#  ['i_321151', 'u_FelixStowe10'],
#  ['i_321151', 'u_J_and_A_1'],
#  ['i_321151', 'u_boston6_8guy'],
#  ['i_321151', 'u_pbh73'],
#  ['i_321151', 'u_pnmdotcom'],
#  ['i_321151', 'u_dre51'],
#  ['i_321151', 'u_Maier'],
#  ['i_321151', 'u_sacanon'],
#  ['i_321151', 'u_MaDunne'],
#  ['i_321151', 'u_workandplay8'],
#  ['i_321151', 'u_GEL1979'],
#  ['i_321151', 'u_fkaway'],
#  ['i_321151', 'u_Tackle'],
#  ['i_321151', 'u_nic1047'],
#  ['i_321151', 'u_AJS2006'],
#  ['i_321151', 'u_Hawaii03'],
#  ['i_321151', 'u_chocolatefriend'],
#  ['i_321151', 'u_Muntz73'],
#  ['i_321151', 'u_kevtee'],
#  ['i_321151', 'u_Nancy875_123'],
#  ['i_321151', 'u_imemine'],
#  ['i_321151', 'u_SportsTraveler'],
#  ['i_321151', 'u_falkirk'],
#  ['i_321151', 'u_matthew.cronin'],
#  ['i_321151', 'u_123cat'],
#  ['i_321151', 'u_Queen_of_NW2'],
#  ['i_321151', 'u_charlotteguy'],
#  ['i_321151', 'u_I_Mallon'],
#  ['i_321151', 'u_Headwall'],
#  ['i_321151', 'u_Msk6261'],
#  ['i_321151', 'u_rdk8'],
#  ['i_321151', 'u_josiegrammer'],
#  ['i_321151', 'u_AtlantaKoko'],
#  ['i_321151', 'u_Angie-travel-junkie'],
#  ['i_321151', 'u_hemba'],
#  ['i_321151', 'u_velsatys'],
#  ['i_559387', 'u_alzo'],
#  ['i_219292', 'u_alzo'],
#  ['i_81397', 'u_alzo'],
#  ['i_302109', 'u_alzo'],
#  ['i_229151', 'u_Traveller from UK'],
#  ['i_217397', 'u_Traveller from UK'],
#  ['i_80930', 'u_Kendo3'],
#  ['i_231526', 'u_Kendo3'],
#  ['i_278074', 'u_Fitzy2'],
#  ['i_89602', 'u_Fitzy2'],
#  ['i_252106', 'u_Fitzy2'],
#  ['i_506418', 'u_Fitzy2'],
#  ['i_230491', 'u_Craigtown'],
#  ['i_93569', 'u_Craigtown'],
#  ['i_77264', 'u_Ben_melb'],
#  ['i_80780', 'u_Ben_melb'],
#  ['i_98726', 'u_Ben_melb'],
#  ['i_224241', 'u_Brian_NVA'],
#  ['i_98710', 'u_Brian_NVA'],
#  ['i_89101', 'u_Brian_NVA'],
#  ['i_78694', 'u_Brian_NVA'],
#  ['i_81038', 'u_Brian_NVA'],
#  ['i_100617', 'u_Brian_NVA'],
#  ['i_209382', 'u_Brian_NVA'],
#  ['i_228728', 'u_Brian_NVA'],
#  ['i_194308', 'u_Brian_NVA'],
#  ['i_313573', 'u_Brian_NVA'],
#  ['i_224168', 'u_Brian_NVA'],
#  ['i_100554', 'u_Brian_NVA'],
#  ['i_620703', 'u_Globe24/7'],
#  ['i_189227', 'u_Globe24/7'],
#  ['i_630596', 'u_Globe24/7'],
#  ['i_229151', 'u_jetlagged7'],
#  ['i_306610', 'u_jetlagged7'],
#  ['i_200948', 'u_janiel'],
#  ['i_277273', 'u_janiel'],
#  ['i_225873', 'u_Tonyeng'],
#  ['i_208454', 'u_Tonyeng'],
#  ['i_596310', 'u_Tonyeng'],
#  ['i_224783', 'u_Tonyeng'],
#  ['i_93477', 'u_Dana_SF'],
#  ['i_199360', 'u_Dana_SF'],
#  ['i_256527', 'u_Baltimoron'],
#  ['i_89602', 'u_Baltimoron'],
#  ['i_232325', 'u_Baltimoron'],
#  ['i_114942', 'u_kenyonmartin2003'],
#  ['i_585414', 'u_kenyonmartin2003'],
#  ['i_289670', 'u_ian_ok'],
#  ['i_222984', 'u_ian_ok'],
#  ['i_259360', 'u_ian_ok'],
#  ['i_620038', 'u_ian_ok'],
#  ['i_234633', 'u_FelixStowe10'],
#  ['i_112360', 'u_FelixStowe10'],
#  ['i_224168', 'u_FelixStowe10'],
#  ['i_227459', 'u_FelixStowe10'],
#  ['i_188743', 'u_J_and_A_1'],
#  ['i_77775', 'u_J_and_A_1'],
#  ['i_305582', 'u_J_and_A_1'],
#  ['i_230616', 'u_J_and_A_1'],
#  ['i_305068', 'u_J_and_A_1'],
#  ['i_236350', 'u_J_and_A_1'],
#  ['i_602600', 'u_J_and_A_1'],
#  ['i_301770', 'u_J_and_A_1'],
#  ['i_256541', 'u_boston6_8guy'],
#  ['i_256618', 'u_boston6_8guy'],
#  ['i_192044', 'u_pbh73'],
#  ['i_268533', 'u_pbh73'],
#  ['i_93457', 'u_pbh73'],
#  ['i_296916', 'u_pnmdotcom'],
#  ['i_223041', 'u_pnmdotcom'],
#  ['i_89158', 'u_dre51'],
#  ['i_191164', 'u_dre51'],
#  ['i_111444', 'u_dre51'],
#  ['i_93507', 'u_Maier'],
#  ['i_208453', 'u_Maier'],
#  ['i_81004', 'u_sacanon'],
#  ['i_81019', 'u_sacanon'],
#  ['i_73957', 'u_sacanon'],
#  ['i_81169', 'u_sacanon'],
#  ['i_228527', 'u_MaDunne'],
#  ['i_93569', 'u_MaDunne'],
#  ['i_595373', 'u_workandplay8'],
#  ['i_114134', 'u_workandplay8'],
#  ['i_217844', 'u_GEL1979'],
#  ['i_277997', 'u_GEL1979'],
#  ['i_224241', 'u_fkaway'],
#  ['i_230574', 'u_fkaway'],
#  ['i_81237', 'u_fkaway'],
#  ['i_231520', 'u_fkaway'],
#  ['i_224948', 'u_Tackle'],
#  ['i_100570', 'u_Tackle'],
#  ['i_80983', 'u_Tackle'],
#  ['i_81669', 'u_Tackle'],
#  ['i_292142', 'u_Tackle'],
#  ['i_81204', 'u_Tackle'],
#  ['i_249712', 'u_Tackle'],
#  ['i_89602', 'u_nic1047'],
#  ['i_258705', 'u_nic1047'],
#  ['i_185406', 'u_nic1047'],
#  ['i_114134', 'u_nic1047'],
#  ['i_255674', 'u_nic1047'],
#  ['i_256659', 'u_nic1047'],
#  ['i_265745', 'u_AJS2006'],
#  ['i_305931', 'u_AJS2006'],
#  ['i_620703', 'u_Hawaii03'],
#  ['i_236068', 'u_Hawaii03'],
#  ['i_618139', 'u_chocolatefriend'],
#  ['i_559726', 'u_chocolatefriend'],
#  ['i_235513', 'u_chocolatefriend'],
#  ['i_93569', 'u_chocolatefriend'],
#  ['i_255674', 'u_chocolatefriend'],
#  ['i_93457', 'u_chocolatefriend'],
#  ['i_301911', 'u_Muntz73'],
#  ['i_77700', 'u_Muntz73'],
#  ['i_230572', 'u_Muntz73'],
#  ['i_256659', 'u_Muntz73'],
#  ['i_249712', 'u_kevtee'],
#  ['i_620038', 'u_kevtee'],
#  ['i_114150', 'u_Nancy875_123'],
#  ['i_254605', 'u_Nancy875_123'],
#  ['i_114942', 'u_imemine'],
#  ['i_100581', 'u_imemine'],
#  ['i_114150', 'u_SportsTraveler'],
#  ['i_217616', 'u_SportsTraveler'],
#  ['i_120684', 'u_falkirk'],
#  ['i_299128', 'u_falkirk'],
#  ['i_219988', 'u_matthew.cronin'],
#  ['i_224877', 'u_matthew.cronin'],
#  ['i_302109', 'u_123cat'],
#  ['i_256629', 'u_123cat'],
#  ['i_548045', 'u_Queen_of_NW2'],
#  ['i_483282', 'u_Queen_of_NW2'],
#  ['i_502408', 'u_charlotteguy'],
#  ['i_99368', 'u_charlotteguy'],
#  ['i_209382', 'u_charlotteguy'],
#  ['i_98679', 'u_charlotteguy'],
#  ['i_93457', 'u_charlotteguy'],
#  ['i_230643', 'u_I_Mallon'],
#  ['i_258705', 'u_I_Mallon'],
#  ['i_191438', 'u_I_Mallon'],
#  ['i_93459', 'u_Headwall'],
#  ['i_89147', 'u_Headwall'],
#  ['i_89148', 'u_Msk6261'],
#  ['i_301787', 'u_Msk6261'],
#  ['i_305371', 'u_Msk6261'],
#  ['i_229679', 'u_Msk6261'],
#  ['i_190149', 'u_Msk6261'],
#  ['i_249712', 'u_Msk6261'],
#  ['i_262330', 'u_Msk6261'],
#  ['i_262569', 'u_rdk8'],
#  ['i_313573', 'u_rdk8'],
#  ['i_281071', 'u_josiegrammer'],
#  ['i_222959', 'u_josiegrammer'],
#  ['i_217626', 'u_josiegrammer'],
#  ['i_194317', 'u_AtlantaKoko'],
#  ['i_100542', 'u_AtlantaKoko'],
#  ['i_300840', 'u_Angie-travel-junkie'],
#  ['i_256649', 'u_Angie-travel-junkie'],
#  ['i_234752', 'u_hemba'],
#  ['i_199395', 'u_hemba'],
#  ['i_206928', 'u_hemba'],
#  ['i_109367', 'u_velsatys'],
#  ['i_114942', 'u_velsatys'],
#  ['i_197534', 'u_velsatys'],
#  ['i_153936', 'u_ladybugx87'],
#  ['i_152463', 'u_ladybugx87'],
#  ['i_638765', 'u_ladybugx87'],
#  ['i_98728', 'u_ladybugx87'],
#  ['i_224168', 'u_ladybugx87'],
#  ['i_255674', 'u_ladybugx87'],
#  ['i_249712', 'u_ladybugx87'],
#  ['i_73799', 'u_ladybugx87'],
#  ['i_153936', 'u_djcn0te'],
#  ['i_153936', 'u_Globo4368'],
#  ['i_153936', 'u_khw225'],
#  ['i_153936', 'u_RAAP'],
#  ['i_153936', 'u_nsmHouston'],
#  ['i_153936', 'u_Nicolas_from_Paris'],
#  ['i_275799', 'u_djcn0te'],
#  ['i_185406', 'u_djcn0te'],
#  ['i_150446', 'u_Globo4368'],
#  ['i_85204', 'u_Globo4368'],
#  ['i_202450', 'u_khw225'],
#  ['i_286358', 'u_khw225'],
#  ['i_232778', 'u_khw225'],
#  ['i_301279', 'u_khw225'],
#  ['i_149399', 'u_RAAP'],
#  ['i_85205', 'u_RAAP'],
#  ['i_224875', 'u_RAAP'],
#  ['i_185401', 'u_nsmHouston'],
#  ['i_80983', 'u_nsmHouston'],
#  ['i_291444', 'u_Nicolas_from_Paris'],
#  ['i_203005', 'u_Nicolas_from_Paris'],
#  ['i_199397', 'u_Nicolas_from_Paris'],
#  ['i_185401', 'u_Nicolas_from_Paris'],
#  ['i_300459', 'u_Nicolas_from_Paris'],
#  ['i_296915', 'u_Nicolas_from_Paris'],
#  ['i_190614', 'u_Nicolas_from_Paris'],
#  ['i_199360', 'u_Nicolas_from_Paris'],
#  ['i_230574', 'u_Nicolas_from_Paris'],
#  ['i_115623', 'u_Nicolas_from_Paris'],
#  ['i_81049', 'u_Nicolas_from_Paris'],
#  ['i_229478', 'u_Nicolas_from_Paris'],
#  ['i_236350', 'u_Nicolas_from_Paris'],
#  ['i_228419', 'u_Nicolas_from_Paris'],
#  ['i_291444', 'u_jobymaloby'],
#  ['i_234572', 'u_jobymaloby'],
#  ['i_296916', 'u_jobymaloby'],
#  ['i_239542', 'u_jobymaloby'],
#  ['i_621785', 'u_jobymaloby'],
#  ['i_291444', 'u_JCLON'],
#  ['i_291444', 'u_yuringa'],
#  ['i_291444', 'u_Globaladventure'],
#  ['i_291444', 'u_Lurkeyme'],
#  ['i_291444', 'u_interpol81'],
#  ['i_291444', 'u_Happyhubby&Daddy'],
#  ['i_291444', 'u_LondonBlonde'],
#  ['i_291444', 'u_Graysgirl'],
#  ['i_291444', 'u_katrineCPH'],
#  ['i_234752', 'u_JCLON'],
#  ['i_585139', 'u_JCLON'],
#  ['i_228728', 'u_JCLON'],
#  ['i_489057', 'u_JCLON'],
#  ['i_229477', 'u_yuringa'],
#  ['i_208454', 'u_yuringa'],
#  ['i_248857', 'u_Globaladventure'],
#  ['i_659532', 'u_Globaladventure'],
#  ['i_506292', 'u_Globaladventure'],
#  ['i_115484', 'u_Globaladventure'],
#  ['i_224221', 'u_Lurkeyme'],
#  ['i_498185', 'u_Lurkeyme'],
#  ['i_202993', 'u_interpol81'],
#  ['i_275858', 'u_interpol81'],
#  ['i_229602', 'u_Happyhubby&Daddy'],
#  ['i_232504', 'u_Happyhubby&Daddy'],
#  ['i_252106', 'u_Happyhubby&Daddy'],
#  ['i_100565', 'u_Happyhubby&Daddy'],
#  ['i_230616', 'u_Happyhubby&Daddy'],
#  ['i_256624', 'u_Happyhubby&Daddy'],
#  ['i_189387', 'u_LondonBlonde'],
#  ['i_285998', 'u_LondonBlonde'],
#  ['i_199360', 'u_Graysgirl'],
#  ['i_84502', 'u_Graysgirl'],
#  ['i_619681', 'u_katrineCPH'],
#  ['i_228621', 'u_katrineCPH'],
#  ['i_543153', 'u_katrineCPH'],
#  ['i_285998', 'u_katrineCPH'],
#  ['i_188937', 'u_katrineCPH'],
#  ['i_497689', 'u_katrineCPH'],
#  ['i_483134', 'u_katrineCPH'],
#  ['i_280630', 'u_jeff1996'],
#  ['i_299568', 'u_jeff1996'],
#  ['i_217616', 'u_jeff1996'],
#  ['i_586662', 'u_jeff1996'],
#  ['i_301577', 'u_jeff1996'],
#  ['i_280630', 'u_Sandokan62'],
#  ['i_280630', 'u_woozal'],
#  ['i_280630', 'u_margarida'],
#  ['i_280630', 'u_Laulaa'],
#  ['i_280630', 'u_connied76'],
#  ['i_280630', 'u_HHChris'],
#  ['i_280630', 'u_alexandrakr'],
#  ['i_280630', 'u_Sun75'],
#  ['i_280630', 'u_LAworld'],
#  ['i_280630', 'u_a visitor from ireland'],
#  ['i_280630', 'u_bandogal'],
#  ['i_85046', 'u_Sandokan62'],
#  ['i_73821', 'u_Sandokan62'],
#  ['i_222984', 'u_Sandokan62'],
#  ['i_77866', 'u_Sandokan62'],
#  ['i_85204', 'u_Sandokan62'],
#  ['i_262330', 'u_Sandokan62'],
#  ['i_301250', 'u_woozal'],
#  ['i_199319', 'u_woozal'],
#  ['i_622666', 'u_margarida'],
#  ['i_276043', 'u_margarida'],
#  ['i_571526', 'u_margarida'],
#  ['i_194317', 'u_Laulaa'],
#  ['i_572859', 'u_Laulaa'],
#  ['i_558796', 'u_connied76'],
#  ['i_192044', 'u_connied76'],
#  ['i_228375', 'u_HHChris'],
#  ['i_262330', 'u_HHChris'],
#  ['i_202272', 'u_alexandrakr'],
#  ['i_289019', 'u_alexandrakr'],
#  ['i_250849', 'u_Sun75'],
#  ['i_275406', 'u_Sun75'],
#  ['i_275581', 'u_LAworld'],
#  ['i_301657', 'u_LAworld'],
#  ['i_304305', 'u_LAworld'],
#  ['i_265476', 'u_LAworld'],
#  ['i_224948', 'u_a visitor from ireland'],
#  ['i_234633', 'u_a visitor from ireland'],
#  ['i_276043', 'u_a visitor from ireland'],
#  ['i_81444', 'u_bandogal'],
#  ['i_1071829', 'u_bandogal'],
#  ['i_313573', 'u_bandogal'],
#  ['i_84064', 'u_WhollyHeretic'],
#  ['i_269966', 'u_WhollyHeretic'],
#  ['i_595373', 'u_WhollyHeretic'],
#  ['i_84064', 'u_dantudor'],
#  ['i_84064', 'u_sallynb'],
#  ['i_84064', 'u_AMP2008London'],
#  ['i_84064', 'u_Jakuch'],
#  ['i_84064', 'u_joelmari'],
#  ['i_84064', 'u_mccarthys5'],
#  ['i_84064', 'u_AaronFWA'],
#  ['i_84064', 'u_BillF'],
#  ['i_84064', 'u_TravelingJournal'],
#  ['i_84064', 'u_muszekfan'],
#  ['i_84064', 'u_HanD'],
#  ['i_84064', 'u_rr1954'],
#  ['i_84064', 'u_Wise_One'],
#  ['i_84064', 'u_FancyDay'],
#  ['i_84064', 'u_travelsavant'],
#  ['i_84064', 'u_seasuzie'],
#  ['i_275581', 'u_dantudor'],
#  ['i_292142', 'u_dantudor'],
#  ['i_120988', 'u_sallynb'],
#  ['i_93467', 'u_sallynb'],
#  ['i_228479', 'u_AMP2008London'],
#  ['i_111423', 'u_AMP2008London'],
#  ['i_217378', 'u_Jakuch'],
#  ['i_256734', 'u_Jakuch'],
#  ['i_292923', 'u_joelmari'],
#  ['i_304289', 'u_joelmari'],
#  ['i_115484', 'u_joelmari'],
#  ['i_81397', 'u_mccarthys5'],
#  ['i_518280', 'u_mccarthys5'],
#  ['i_190149', 'u_AaronFWA'],
#  ['i_235981', 'u_AaronFWA'],
#  ['i_260822', 'u_AaronFWA'],
#  ['i_81803', 'u_BillF'],
#  ['i_120988', 'u_BillF'],
#  ['i_256541', 'u_BillF'],
#  ['i_305813', 'u_TravelingJournal'],
#  ['i_603403', 'u_TravelingJournal'],
#  ['i_80756', 'u_muszekfan'],
#  ['i_81803', 'u_muszekfan'],
#  ['i_603403', 'u_HanD'],
#  ['i_305905', 'u_HanD'],
#  ['i_115754', 'u_rr1954'],
#  ['i_268533', 'u_rr1954'],
#  ['i_98710', 'u_Wise_One'],
#  ['i_319066', 'u_Wise_One'],
#  ['i_241678', 'u_Wise_One'],
#  ['i_151713', 'u_FancyDay'],
#  ['i_151827', 'u_FancyDay'],
#  ['i_317155', 'u_FancyDay'],
#  ['i_98606', 'u_travelsavant'],
#  ['i_654030', 'u_travelsavant'],
#  ['i_98726', 'u_travelsavant'],
#  ['i_81022', 'u_travelsavant'],
#  ['i_249712', 'u_travelsavant'],
#  ['i_676408', 'u_seasuzie'],
#  ['i_224168', 'u_seasuzie'],
#  ['i_305877', 'u_alanyeo76'],
#  ['i_301573', 'u_alanyeo76'],
#  ['i_306166', 'u_alanyeo76'],
#  ['i_301577', 'u_alanyeo76'],
#  ['i_301581', 'u_alanyeo76'],
#  ['i_305877', 'u_charliebrownsnoopy'],
#  ['i_305877', 'u_enjoytravel'],
#  ['i_305877', 'u_Kat33'],
#  ['i_305877', 'u_namisuki'],
#  ['i_614236', 'u_charliebrownsnoopy'],
#  ['i_282300', 'u_charliebrownsnoopy'],
#  ['i_149395', 'u_enjoytravel'],
#  ['i_206992', 'u_enjoytravel'],
#  ['i_304485', 'u_Kat33'],
#  ['i_583733', 'u_Kat33'],
#  ['i_307332', 'u_namisuki'],
#  ['i_114008', 'u_namisuki'],
#  ['i_111978', 'u_mellow_goat'],
#  ['i_93047', 'u_mellow_goat'],
#  ['i_498233', 'u_mellow_goat'],
#  ['i_111978', 'u_jlr51'],
#  ['i_111978', 'u_okguy2937'],
#  ['i_111978', 'u_DebbaJoy'],
#  ['i_89147', 'u_jlr51'],
#  ['i_93034', 'u_jlr51'],
#  ['i_112007', 'u_okguy2937'],
#  ['i_89148', 'u_okguy2937'],
#  ['i_223133', 'u_okguy2937'],
#  ['i_111969', 'u_okguy2937'],
#  ['i_89118', 'u_okguy2937'],
#  ['i_112303', 'u_DebbaJoy'],
#  ['i_115754', 'u_DebbaJoy'],
#  ['i_228636', 'u_craigpatt'],
#  ['i_595373', 'u_craigpatt'],
#  ['i_947611', 'u_craigpatt'],
#  ['i_228636', 'u_jimalbe'],
#  ['i_228636', 'u_Huuhkaja'],
#  ['i_228636', 'u_jojomillar'],
#  ['i_228636', 'u_Charlie_Lon'],
#  ['i_228636', 'u_kittyhola'],
#  ['i_228636', 'u_torretta'],
#  ['i_228636', 'u_MatthewRob'],
#  ['i_228636', 'u_jcniii'],
#  ['i_228636', 'u_Ricardfred'],
#  ['i_228636', 'u_Bel1'],
#  ['i_228636', 'u_jampi10'],
#  ['i_229679', 'u_jimalbe'],
#  ['i_675157', 'u_jimalbe'],
#  ['i_306176', 'u_Huuhkaja'],
#  ['i_231502', 'u_Huuhkaja'],
#  ['i_260365', 'u_Huuhkaja'],
#  ['i_255673', 'u_Huuhkaja'],
#  ['i_530096', 'u_Huuhkaja'],
#  ['i_281960', 'u_Huuhkaja'],
#  ['i_208454', 'u_jojomillar'],
#  ['i_621785', 'u_jojomillar'],
#  ['i_199397', 'u_Charlie_Lon'],
#  ['i_202459', 'u_Charlie_Lon'],
#  ['i_266322', 'u_Charlie_Lon'],
#  ['i_81042', 'u_Charlie_Lon'],
#  ['i_498328', 'u_Charlie_Lon'],
#  ['i_281071', 'u_kittyhola'],
#  ['i_229677', 'u_kittyhola'],
#  ['i_235644', 'u_kittyhola'],
#  ['i_281071', 'u_torretta'],
#  ['i_202993', 'u_torretta'],
#  ['i_279283', 'u_torretta'],
#  ['i_195855', 'u_torretta'],
#  ['i_111751', 'u_torretta'],
#  ['i_208210', 'u_MatthewRob'],
#  ['i_574449', 'u_MatthewRob'],
#  ['i_301787', 'u_MatthewRob'],
#  ['i_758191', 'u_MatthewRob'],
#  ['i_232782', 'u_jcniii'],
#  ['i_93507', 'u_jcniii'],
#  ['i_100603', 'u_jcniii'],
#  ['i_258824', 'u_jcniii'],
#  ['i_227459', 'u_jcniii'],
#  ['i_190616', 'u_Ricardfred'],
#  ['i_93340', 'u_Ricardfred'],
#  ['i_229164', 'u_Ricardfred'],
#  ['i_80836', 'u_Ricardfred'],
#  ['i_563485', 'u_Bel1'],
#  ['i_199310', 'u_Bel1'],
#  ['i_578305', 'u_jampi10'],
#  ['i_289670', 'u_jampi10'],
#  ['i_228563', 'u_jampi10'],
#  ['i_585139', 'u_jampi10'],
#  ['i_255650', 'u_jampi10'],
#  ['i_501108', 'u_jampi10'],
#  ['i_630596', 'u_jampi10'],
#  ['i_188746', 'u_c.h.s.p'],
#  ['i_202993', 'u_c.h.s.p'],
#  ['i_618139', 'u_c.h.s.p'],
#  ['i_188746', 'u_Critical_But_Fair'],
#  ['i_188746', 'u_slocal'],
#  ['i_188746', 'u_Spoda'],
#  ['i_188746', 'u_jltaylor'],
#  ['i_188746', 'u_pitttrader1988'],
#  ['i_188746', 'u_Trip Advisor from Dallas, TX'],
#  ['i_188746', 'u_tripdenver'],
#  ['i_188746', 'u_njpsufan'],
#  ['i_81126', 'u_Critical_But_Fair'],
#  ['i_112328', 'u_Critical_But_Fair'],
#  ['i_115484', 'u_Critical_But_Fair'],
#  ['i_296916', 'u_slocal'],
#  ['i_93589', 'u_slocal'],
#  ['i_81394', 'u_slocal'],
#  ['i_620038', 'u_slocal'],
#  ['i_233866', 'u_Spoda'],
#  ['i_237567', 'u_Spoda'],
#  ['i_302434', 'u_Spoda'],
#  ['i_299606', 'u_jltaylor'],
#  ['i_325490', 'u_jltaylor'],
#  ['i_305861', 'u_jltaylor'],
#  ['i_301431', 'u_pitttrader1988'],
#  ['i_587052', 'u_pitttrader1988'],
#  ['i_299128', 'u_pitttrader1988'],
#  ['i_195703', 'u_Trip Advisor from Dallas, TX'],
#  ['i_202274', 'u_Trip Advisor from Dallas, TX'],
#  ['i_229602', 'u_tripdenver'],
#  ['i_81110', 'u_tripdenver'],
#  ['i_259397', 'u_njpsufan'],
#  ['i_187737', 'u_njpsufan'],
#  ['i_259397', 'u_Moth'],
#  ['i_256627', 'u_Moth'],
#  ['i_302012', 'u_Moth'],
#  ['i_304289', 'u_Moth'],
#  ['i_249712', 'u_Moth'],
#  ['i_259397', 'u_M747'],
#  ['i_259397', 'u_CATrvl08'],
#  ['i_259397', 'u_espengc'],
#  ['i_259397', 'u_kecoco'],
#  ['i_259397', 'u_raven40'],
#  ['i_259397', 'u_Spamstan'],
#  ['i_259397', 'u_StephanieinOntario'],
#  ['i_259397', 'u_English_Traveller-7'],
#  ['i_259397', 'u_Franchise35'],
#  ['i_259397', 'u_Craven'],
#  ['i_259397', 'u_enofile1'],
#  ['i_259397', 'u_corgimomDallas'],
#  ['i_259397', 'u_beachlover325'],
#  ['i_259397', 'u_SkyeTraveler'],
#  ['i_259397', 'u_Northerngirl1'],
#  ['i_81985', 'u_M747'],
#  ['i_126260', 'u_M747'],
#  ['i_229497', 'u_M747'],
#  ['i_81397', 'u_M747'],
#  ['i_208454', 'u_M747'],
#  ['i_306610', 'u_M747'],
#  ['i_497689', 'u_M747'],
#  ['i_111751', 'u_M747'],
#  ['i_289019', 'u_M747'],
#  ['i_81985', 'u_CATrvl08'],
#  ['i_98731', 'u_CATrvl08'],
#  ['i_126260', 'u_CATrvl08'],
#  ['i_98629', 'u_CATrvl08'],
#  ['i_89083', 'u_CATrvl08'],
#  ['i_225873', 'u_espengc'],
#  ['i_209382', 'u_espengc'],
#  ['i_208454', 'u_kecoco'],
#  ['i_288592', 'u_kecoco'],
#  ['i_224783', 'u_kecoco'],
#  ['i_256655', 'u_raven40'],
#  ['i_73943', 'u_raven40'],
#  ['i_80087', 'u_Spamstan'],
#  ['i_89575', 'u_Spamstan'],
#  ['i_674915', 'u_Spamstan'],
#  ['i_81985', 'u_StephanieinOntario'],
#  ['i_647813', 'u_StephanieinOntario'],
#  ['i_81461', 'u_StephanieinOntario'],
#  ['i_235513', 'u_English_Traveller-7'],
#  ['i_94326', 'u_English_Traveller-7'],
#  ['i_87102', 'u_Franchise35'],
#  ['i_230119', 'u_Franchise35'],
#  ['i_291544', 'u_Craven'],
#  ['i_559387', 'u_Craven'],
#  ['i_300855', 'u_Craven'],
#  ['i_93507', 'u_enofile1'],
#  ['i_89115', 'u_enofile1'],
#  ['i_185406', 'u_enofile1'],
#  ['i_230103', 'u_enofile1'],
#  ['i_200257', 'u_enofile1'],
#  ['i_80797', 'u_enofile1'],
#  ['i_223041', 'u_enofile1'],
#  ['i_262330', 'u_enofile1'],
#  ['i_77804', 'u_corgimomDallas'],
#  ['i_268533', 'u_corgimomDallas'],
#  ['i_647813', 'u_beachlover325'],
#  ['i_100505', 'u_beachlover325'],
#  ['i_89600', 'u_beachlover325'],
#  ['i_85192', 'u_beachlover325'],
#  ['i_508162', 'u_beachlover325'],
#  ['i_234752', 'u_SkyeTraveler'],
#  ['i_224221', 'u_SkyeTraveler'],
#  ['i_87017', 'u_SkyeTraveler'],
#  ['i_114024', 'u_SkyeTraveler'],
#  ['i_254605', 'u_SkyeTraveler'],
#  ['i_81103', 'u_SkyeTraveler'],
#  ['i_190569', 'u_SkyeTraveler'],
#  ['i_100569', 'u_SkyeTraveler'],
#  ['i_188937', 'u_SkyeTraveler'],
#  ['i_268507', 'u_SkyeTraveler'],
#  ['i_208454', 'u_SkyeTraveler'],
#  ['i_235644', 'u_SkyeTraveler'],
#  ['i_214688', 'u_SkyeTraveler'],
#  ['i_195703', 'u_Northerngirl1'],
#  ['i_268507', 'u_Northerngirl1'],
#  ['i_278074', 'u_JP3CHICAGO'],
#  ['i_195007', 'u_JP3CHICAGO'],
#  ['i_149921', 'u_JP3CHICAGO'],
#  ['i_548045', 'u_JP3CHICAGO'],
#  ['i_77944', 'u_JP3CHICAGO'],
#  ['i_115754', 'u_JP3CHICAGO'],
#  ['i_278074', 'u_newyorklover123'],
#  ['i_278074', 'u_Veryfussy'],
#  ['i_278074', 'u_Ravenduffer'],
#  ['i_278074', 'u_Clefsdorsf'],
#  ['i_278074', 'u_johnshen65'],
#  ['i_278074', 'u_DNewYork'],
#  ['i_278074', 'u_investr'],
#  ['i_278074', 'u_SSS2005'],
#  ['i_278074', 'u_roar_03'],
#  ['i_278074', 'u_KSergey'],
#  ['i_278074', 'u_TravelDIVA3'],
#  ['i_278074', 'u_saintba'],
#  ['i_278074', 'u_ACPACPACP'],
#  ['i_278074', 'u_lagniappe34'],
#  ['i_278074', 'u_BrynMawrBK'],
#  ['i_278074', 'u_andrea.italian'],
#  ['i_278074', 'u_FMUBSU'],
#  ['i_278074', 'u_hardingk'],
#  ['i_278074', 'u_CTKnowItAll'],
#  ['i_278074', 'u_NikiC'],
#  ['i_278074', 'u_allesandra'],
#  ['i_278074', 'u_shamrock02'],
#  ['i_126260', 'u_newyorklover123'],
#  ['i_89585', 'u_newyorklover123'],
#  ['i_224224', 'u_newyorklover123'],
#  ['i_302040', 'u_Veryfussy'],
#  ['i_190694', 'u_Veryfussy'],
#  ['i_222912', 'u_Ravenduffer'],
#  ['i_81209', 'u_Ravenduffer'],
#  ['i_90015', 'u_Clefsdorsf'],
#  ['i_112179', 'u_Clefsdorsf'],
#  ['i_114024', 'u_Clefsdorsf'],
#  ['i_190617', 'u_Clefsdorsf'],
#  ['i_76442', 'u_Clefsdorsf'],
#  ['i_305813', 'u_johnshen65'],
#  ['i_256624', 'u_johnshen65'],
#  ['i_111751', 'u_DNewYork'],
#  ['i_224877', 'u_DNewYork'],
#  ['i_548045', 'u_investr'],
#  ['i_98629', 'u_investr'],
#  ['i_585204', 'u_investr'],
#  ['i_301468', 'u_SSS2005'],
#  ['i_114134', 'u_SSS2005'],
#  ['i_299128', 'u_SSS2005'],
#  ['i_574449', 'u_roar_03'],
#  ['i_235513', 'u_roar_03'],
#  ['i_224953', 'u_roar_03'],
#  ['i_288592', 'u_roar_03'],
#  ['i_192064', 'u_KSergey'],
#  ['i_93477', 'u_KSergey'],
#  ['i_93338', 'u_KSergey'],
#  ['i_252106', 'u_KSergey'],
#  ['i_208454', 'u_KSergey'],
#  ['i_302653', 'u_TravelDIVA3'],
#  ['i_301911', 'u_TravelDIVA3'],
#  ['i_81215', 'u_TravelDIVA3'],
#  ['i_307571', 'u_TravelDIVA3'],
#  ['i_208453', 'u_saintba'],
#  ['i_259593', 'u_saintba'],
#  ['i_81126', 'u_saintba'],
#  ['i_85204', 'u_saintba'],
#  ['i_188975', 'u_saintba'],
#  ['i_630305', 'u_saintba'],
#  ['i_262330', 'u_saintba'],
#  ['i_281071', 'u_ACPACPACP'],
#  ['i_190614', 'u_ACPACPACP'],
#  ['i_185406', 'u_ACPACPACP'],
#  ['i_224783', 'u_ACPACPACP'],
#  ['i_120831', 'u_lagniappe34'],
#  ['i_89101', 'u_lagniappe34'],
#  ['i_259360', 'u_lagniappe34'],
#  ['i_120852', 'u_lagniappe34'],
#  ['i_89083', 'u_lagniappe34'],
#  ['i_224877', 'u_lagniappe34'],
#  ['i_602600', 'u_lagniappe34'],
#  ['i_502408', 'u_BrynMawrBK'],
#  ['i_281071', 'u_BrynMawrBK'],
#  ['i_224224', 'u_BrynMawrBK'],
#  ['i_281071', 'u_andrea.italian'],
#  ['i_580687', 'u_andrea.italian'],
#  ['i_224953', 'u_andrea.italian'],
#  ['i_301468', 'u_FMUBSU'],
#  ['i_301883', 'u_FMUBSU'],
#  ['i_100537', 'u_FMUBSU'],
#  ['i_307571', 'u_FMUBSU'],
#  ['i_548045', 'u_FMUBSU'],
#  ['i_150241', 'u_hardingk'],
#  ['i_89575', 'u_hardingk'],
#  ['i_80275', 'u_hardingk'],
#  ['i_262330', 'u_hardingk'],
#  ['i_148042', 'u_CTKnowItAll'],
#  ['i_222959', 'u_CTKnowItAll'],
#  ['i_189387', 'u_NikiC'],
#  ['i_249488', 'u_NikiC'],
#  ['i_508162', 'u_NikiC'],
#  ['i_148807', 'u_NikiC'],
#  ['i_191159', 'u_allesandra'],
#  ['i_574449', 'u_allesandra'],
#  ['i_188729', 'u_allesandra'],
#  ['i_281071', 'u_shamrock02'],
#  ['i_630409', 'u_shamrock02'],
#  ['i_578305', 'u_krislecl'],
#  ['i_81315', 'u_krislecl'],
#  ['i_195007', 'u_krislecl'],
#  ['i_285955', 'u_krislecl'],
#  ['i_578305', 'u_MysticKid'],
#  ['i_578305', 'u_GEOFFS3'],
#  ['i_578305', 'u_SueFee'],
#  ['i_578305', 'u_mpugs'],
#  ['i_578305', 'u_MissMyDog'],
#  ['i_578305', 'u_SandSunandSea'],
#  ['i_578305', 'u_alaskan_itchy-feet'],
#  ['i_578305', 'u_Sharonb423'],
#  ['i_578305', 'u_StephenWard'],
#  ['i_578305', 'u_Greataunt'],
#  ['i_578305', 'u_ElleSheri'],
#  ['i_578305', 'u_1972j'],
#  ['i_578305', 'u_artfam'],
#  ['i_578305', 'u_Craigy'],
#  ['i_578305', 'u_Jenniferanne'],
#  ['i_578305', 'u_Shopaholiday'],
#  ['i_578305', 'u_Shmohan'],
#  ['i_578305', 'u_Davidwatts'],
#  ['i_578305', 'u_leftwing'],
#  ['i_578305', 'u_coco40'],
#  ['i_578305', 'u_sleepy510'],
#  ['i_578305', 'u_alisa110'],
#  ['i_578305', 'u_Mainers'],
#  ['i_578305', 'u_izlo'],
#  ['i_578305', 'u_hubert'],
#  ['i_578305', 'u_tahiti05'],
#  ['i_578305', 'u_SeminarTrekker'],
#  ['i_578305', 'u_frank2007'],
#  ['i_578305', 'u_Cleeclub'],
#  ['i_578305', 'u_Mr Steve-1'],
#  ['i_578305', 'u_lopo147'],
#  ['i_578305', 'u_Ryan.W'],
#  ['i_578305', 'u_MR_PHL'],
#  ['i_578305', 'u_DesMoines'],
#  ['i_578305', 'u_jamwilson'],
#  ['i_89602', 'u_MysticKid'],
#  ['i_296606', 'u_MysticKid'],
#  ['i_74626', 'u_MysticKid'],
#  ['i_277997', 'u_MysticKid'],
#  ['i_219988', 'u_MysticKid'],
#  ['i_100562', 'u_GEOFFS3'],
#  ['i_99368', 'u_GEOFFS3'],
#  ['i_89101', 'u_GEOFFS3'],
#  ['i_100597', 'u_GEOFFS3'],
#  ['i_675165', 'u_GEOFFS3'],
#  ['i_585414', 'u_GEOFFS3'],
#  ['i_80912', 'u_GEOFFS3'],
#  ['i_119355', 'u_GEOFFS3'],
#  ['i_73757', 'u_GEOFFS3'],
#  ['i_208453', 'u_SueFee'],
#  ['i_94326', 'u_SueFee'],
#  ['i_262330', 'u_SueFee'],
#  ['i_218100', 'u_mpugs'],
#  ['i_85029', 'u_mpugs'],
#  ['i_275261', 'u_MissMyDog'],
#  ['i_84455', 'u_MissMyDog'],
#  ['i_209382', 'u_MissMyDog'],
#  ['i_93507', 'u_SandSunandSea'],
#  ['i_247957', 'u_SandSunandSea'],
#  ['i_93457', 'u_SandSunandSea'],
#  ['i_241746', 'u_alaskan_itchy-feet'],
#  ['i_223955', 'u_alaskan_itchy-feet'],
#  ['i_234752', 'u_Sharonb423'],
#  ['i_89620', 'u_Sharonb423'],
#  ['i_77804', 'u_StephenWard'],
#  ['i_223955', 'u_StephenWard'],
#  ['i_77944', 'u_Greataunt'],
#  ['i_85031', 'u_Greataunt'],
#  ['i_234752', 'u_ElleSheri'],
#  ['i_87011', 'u_ElleSheri'],
#  ['i_571526', 'u_ElleSheri'],
#  ['i_80747', 'u_ElleSheri'],
#  ['i_99368', 'u_1972j'],
#  ['i_498185', 'u_1972j'],
#  ['i_319066', 'u_artfam'],
#  ['i_111983', 'u_artfam'],
#  ['i_87040', 'u_Craigy'],
#  ['i_119657', 'u_Craigy'],
#  ['i_87016', 'u_Craigy'],
#  ['i_81038', 'u_Craigy'],
#  ['i_122020', 'u_Craigy'],
#  ['i_112325', 'u_Craigy'],
#  ['i_255650', 'u_Craigy'],
#  ['i_81049', 'u_Craigy'],
#  ['i_87090', 'u_Craigy'],
#  ['i_194308', 'u_Jenniferanne'],
#  ['i_84502', 'u_Jenniferanne'],
#  ['i_305813', 'u_Shopaholiday'],
#  ['i_502408', 'u_Shopaholiday'],
#  ['i_98719', 'u_Shmohan'],
#  ['i_280902', 'u_Shmohan'],
#  ['i_305371', 'u_Davidwatts'],
#  ['i_87108', 'u_Davidwatts'],
#  ['i_114134', 'u_leftwing'],
#  ['i_111974', 'u_leftwing'],
#  ['i_99371', 'u_coco40'],
#  ['i_518280', 'u_coco40'],
#  ['i_660350', 'u_coco40'],
#  ['i_310780', 'u_sleepy510'],
#  ['i_149397', 'u_sleepy510'],
#  ['i_292142', 'u_sleepy510'],
#  ['i_478252', 'u_sleepy510'],
#  ['i_289202', 'u_sleepy510'],
#  ['i_319066', 'u_alisa110'],
#  ['i_602600', 'u_alisa110'],
#  ['i_229621', 'u_Mainers'],
#  ['i_111444', 'u_Mainers'],
#  ['i_93534', 'u_Mainers'],
#  ['i_224248', 'u_izlo'],
#  ['i_85204', 'u_izlo'],
#  ['i_256627', 'u_hubert'],
#  ['i_112307', 'u_hubert'],
#  ['i_292142', 'u_hubert'],
#  ['i_77804', 'u_tahiti05'],
#  ['i_208082', 'u_tahiti05'],
#  ['i_249712', 'u_tahiti05'],
#  ['i_125161', 'u_SeminarTrekker'],
#  ['i_81315', 'u_SeminarTrekker'],
#  ['i_81444', 'u_SeminarTrekker'],
#  ['i_81192', 'u_SeminarTrekker'],
#  ['i_81103', 'u_SeminarTrekker'],
#  ['i_93147', 'u_SeminarTrekker'],
#  ['i_224168', 'u_SeminarTrekker'],
#  ['i_292142', 'u_SeminarTrekker'],
#  ['i_81459', 'u_SeminarTrekker'],
#  ['i_224783', 'u_SeminarTrekker'],
#  ['i_80999', 'u_SeminarTrekker'],
#  ...]

# %%
with open('posi_data.pickle', 'wb') as f:
    pickle.dump(posi_data, f)
with open('nega_data.pickle', 'wb') as f:
    pickle.dump(nega_data, f)

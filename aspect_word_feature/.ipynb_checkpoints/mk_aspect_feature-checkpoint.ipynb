# %% [markdown]
# # aspectの特徴量を作る

# %%
import codecs
import pickle
import glob

# %% [markdown]
# ### 各aspect = topicの単語読み込み

# %%
topic_word = []
with codecs.open('hotel_bootstrapping_lda.dat', 'r', 'utf-8') as f:
    for l in f:
        topic_word.append(l.split(' ')[1:])

# %% [markdown]
# ### userリストとネットワーク読み込み

# %%
KG = pickle.load(open('../../knowledge_graph/trip_ad/trip_ad_graph.pickle', 'rb'))
print(len(KG.edges()))
print(len(KG.nodes()))


edges = list(KG.edges())
# implicit feedback のedgeを格納
implicit_feedback = []

for e in edges:
    if e[0][0:2] == 'u_':
        implicit_feedback.append(e)
    elif e[1][0:2] == 'u_':
        implicit_feedback.append(e)
# Out:
# 30191
# 8074

# %%
user2idx = {}
item2idx = {}
user_list = []
item_list = []

for f in implicit_feedback:
    if f[0][0:2] == 'u_':
        user = f[0]
        item = f[1]
    else:
        user = f[1]
        item = f[0]
        
    if user not in user2idx:
        user2idx[user] = len(user2idx)
        
        
user_list = list(user2idx)

print('user :{}'.format(len(user_list)))
# Out:
# user :6134

# %% [markdown]
# ### userのレビュー読み込み
# - user-reviewの辞書を作る

# %%
# user-reviewの辞書を作る

user2review = {}
hotel_list = glob.glob('../../dataset/TripAdvisor/hotel_review/hotel*')

count = 0

for hotel in hotel_list:
    with codecs.open(hotel, 'r', 'utf-8') as f:
        user = ''
        for l in f:
            if l[0:3] == '<Au':
                user = l[8:]
                
            if l[0:3] == '<Co':
                if user in user2review:
                    user2review[user] = user2review[user] + l[9:]
                else:
                    print(user)
                    user2review[user] = l[9:]
                user = ''
    count += 1
    if count > 5: 
        break
# Out:
# itraveltotravel
#
#
# DwayneDibley
#
# ae398
#
# SouthamFabrice
#
# Limmon
#
# Octofuzz
#
# cybergrrl6
#
# maria035
#
# VidaLocaRanch
#
# blhappypets
#
# HelenBristol
#
# East-House
#
# PVH068
#
# Julka
#
# nduk
#
# gringaviajera
#
# ivanoff123
#
# superEmy
#
# ConnedByMonteCarlo
#
# EuroFloyd
#
# thelimopit
#
# Acasto
#
# CanariesPA
#
# pinnacle306
#
# HJ123
#
# fzemma
#
# aljung
#
# fh1234
#
# HelenD020
#
# ravina
#
# Ainol-Razman
#
# Travellers095
#
# kiwikidNewZealand
#
# SaraandAnna
#
# FMAM
#
# il0veparis
#
# Writerwriter
#
# Danna074
#
# Chjenny
#
# itsumo_no
#
# franco037
#
# happytravellers90
#
# CanuckTraveller07
#
# sarah095
#
# Anna_von_M
#
# traveler581
#
# calderara
#
# etravel2007
#
# StingrayLincolnUK
#
# levitt
#
# Shazzy1
#
# neuehaff
#
# victorylehmann
#
# Canada14
#
# Wanderingaroundabout
#
# Alimac04
#
# bing1978
#
# GandT16
#
# Laura_go_go
#
# roles
#
# williamthorn2
#
# ArronHendy
#
# rythmicjane
#
# jonny55
#
# laylo
#
# Lilysteel
#
# traveller275
#
# IHateAirplanes
#
# andrewbis
#
# peter522
#
# friends4
#
# TripsterUk
#
# lesked
#
# connaught
#
# janus81
#
# parisloverBarcelona
#
# travellerOsaka
#
# Boubouche
#
# happyday46
#
# kingfisher
#
# jessika18
#
# absolutstyle
#
# sallyHereford
#
# mergind
#
# stathy
#
# kleins
#
# TravelingHoyt
#
# chansteve
#
# bouillonjohn
#
# adamrus
#
# Maggiehh
#
# ewenchris
#
# mikihouse
#
# jenmorris
#
# lm33
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# bobalyssa
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# atlr
#
# agro
#
# A TripAdvisor Member
#
# deeguy
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# littlelioness
#
# Insolence_78
#
# lass=
#
# GGala
#
# agnesagnes00
#
# anne044
#
# lass=
#
# muert
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# nono4781
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# vegaslover73
#
# hdettmann
#
# honeynugget
#
# magauran8
#
# wendychivas52
#
# Jimgloria
#
# mywifetakesme
#
# chemical_laser
#
# Hawaii50
#
# KonaTraveler55
#
# wildflowerb
#
# SydTraveller08
#
# barbiespice99
#
# NeedATravelFix
#
# Lisanicole
#
# MKK33
#
# limegreencoco
#
# mulligna
#
# abc08
#
# Kate056
#
# stephiej
#
# Brokenback
#
# Hawaii50Sanfrancisco
#
# emandjeff
#
# Elly08
#
# xbioman
#
# shiina
#
# mjamesChicago
#
# lilajane20
#
# GeorgeFarris
#
# whode
#
# KHFan29
#
# firemaz
#
# radio71
#
# L222
#
# Spaceman58
#
# wanderlust333
#
# Travelguy1972
#
# SUZIELOU
#
# courteliz
#
# Pharmatraveler
#
# kdlOklahoma
#
# oleh-oleh
#
# kadelia
#
# SassyMag
#
# nymark2
#
# ChicagoRory
#
# renotahoe
#
# MattNY
#
# rhodeweary
#
# 68DodgeDart
#
# pengysan
#
# blackburn77
#
# ktk1005
#
# donnalynns2
#
# JerseyJ24
#
# SunCat3
#
# beacho
#
# Kinderteacher4
#
# wine4et
#
# jwilbourn
#
# bookfreak55
#
# GlobeTrotter345
#
# KelownaGirl_78
#
# corky_c
#
# IllinoisHawaiifan
#
# travelswithmimi
#
# Quality_Queen
#
# Nicmacco
#
# AgentJim
#
# 771323
#
# rjlovestotravel
#
# Honey08
#
# Dad-with-2-kids
#
# Spellspinner
#
# k2kelley
#
# eatsoup
#
# krdavids
#
# OldOkie
#
# LouReid
#
# garyswilcox
#
# Dixiechick47
#
# skyservicemiami
#
# SPGryphon
#
# tsgc2008
#
# makamae04
#
# jeanniepep
#
# erinmdil
#
# Ms_Meredith
#
# wendy1461
#
# TrvlDva
#
# funseekers88
#
# time2vacation
#
# qaz123
#
# Hawaiiantraveler66
#
# ronyanbu
#
# YYZflytoomuch
#
# ChiefExec
#
# hawaiigirl7
#
# OHtraveler4
#
# CamilleinCali
#
# AngieDuenas
#
# SammyJo22
#
# GeorgiaPalmtrees
#
# wymzikal82
#
# starsfan96
#
# mike-lcf
#
# ccy2
#
# RodneyB
#
# DubaiUS
#
# cd896
#
# mainelynn
#
# lnew1gd1
#
# U2Fans
#
# tripperATL
#
# ExtolNomad
#
# Eric_Beylon
#
# pixiesnake
#
# cashem
#
# thecommish46
#
# Klasdude
#
# katie516
#
# JANE*20
#
# Kinsa
#
# miltonlover
#
# mtec
#
# Timwestcreek
#
# bums
#
# junemoon
#
# TheThreeTravelers
#
# Ca_natives
#
# Jaquesspratt
#
# J23xx
#
# trixi22
#
# keikimilia
#
# cowboyshater
#
# miss_chris1
#
# Shull
#
# ike7101
#
# Bryan242
#
# shanghaiied
#
# mapwhe
#
# micheallo
#
# ASCMMC
#
# zeimet1
#
# olimaspecto
#
# bm722
#
# cometman
#
# BDJoe
#
# Pt_Fwd
#
# BB100
#
# Davidwatts
#
# SanDiegotravelbug
#
# pha1226
#
# KahunaMon
#
# brooks02151
#
# 30000ft
#
# IzzyRules
#
# BetterthanBings
#
# DenverWing
#
# holagato
#
# laurengucsb
#
# Sheila88
#
# gmadonna
#
# A TripAdvisor Member
#
# kasice
#
# pointe201
#
# FrequentFrier
#
# mmarks72
#
# lsciarra
#
# tgw5631
#
# uskuhlmans
#
# beachgirl48
#
# A TripAdvisor Member
#
# TC1
#
# ydougher
#
# DMNWA
#
# BigAl77
#
# trip101
#
# 4upstateNY
#
# Lovetospend
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# WaikikiQueen
#
# A TripAdvisor Member
#
# Deb249
#
# A TripAdvisor Member
#
# danwhy
#
# A TripAdvisor Member
#
# Lyn2Go
#
# cfd
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# tequilatamm
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# sarahc123
#
# A TripAdvisor Member
#
# lightsleeper1
#
# A TripAdvisor Member
#
# love2trabel
#
# waikikikid
#
# bobster
#
# Cambridgtravler
#
# A TripAdvisor Member
#
# daisysmom
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# goldendeal
#
# diazhill
#
# A TripAdvisor Member
#
# lovetotravelnyc
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# lance92270
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# sleep7
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# RPRINC
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# ken240
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# mswoojie
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# 銇裤仯銇°兗鈾?> 銇裤仯銇°兗鈾?</a> </div>
#
# yutoraia
#
# hmht
#
# sweetie7Japan
#
# 銈广偍銇°們銈?> 銈广偍銇°們銈?</a> </div>
#
# otonozo
#
# 銇娿仯銇愩倱
#
# 銈枫儳銈炽儵
#
# HDCAM
#
# lass=
#
# lass=
#
# lass=
#
# oscaretyouri
#
# lass=
#
# kazubon
#
# 銇倐銇ｃ仚銈?> 銇倐銇ｃ仚銈?</a> </div>
#
# kanpari
#
# 銈傘倐銈撱亴
#
# kazu8
#
# 銇嶃個銇?> 銇嶃個銇?</a> </div>
#
# skyweb
#
# Yamato1111
#
# Hawaii濂姐亶鈾?> Hawaii濂姐亶鈾?</a> </div>
#
# 銈€銉笺倱
#
# lass=
#
# 銇娿仚銇?> 銇娿仚銇?</a> </div>
#
# 銈儐銈ｃ兗
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# mimi_mimi_0517
#
# noripple
#
# tomoeai
#
# kitayuka
#
# lass=
#
# 銇曘亗銇?> 銇曘亗銇?</a> </div>
#
# lass=
#
# lass=
#
# chienyan
#
# miki222
#
# lass=
#
# lass=
#
# kashiwareysol
#
# madoka_jojo831
#
# 銇傘仌銇勩仭
#
# lass=
#
# 銇倞銇斻倱
#
# tomohei
#
# lass=
#
# 钀屻仭銈冦倱
#
# lass=
#
# lass=
#
# lass=
#
# tsukushi
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# SteffiBerlin
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# travelingGangof6
#
# Patty2Rome
#
# pfply
#
# craig2
#
# HeartMath
#
# HenriNewYork
#
# Carinanne
#
# Ladybug9988
#
# MotherPup
#
# luckynaka
#
# j1adc
#
# Fletcher417
#
# TKlash
#
# JohnThomas1969
#
# Pepifray
#
# Besos15
#
# PhxED
#
# Jess451
#
# Dbob
#
# apetura
#
# herbnkim
#
# CaliforniaWildchild
#
# vista4u
#
# vischa
#
# mmnb
#
# LottyPotty
#
# TLL2008
#
# corgs78
#
# billerm
#
# johar1
#
# Innqueen1
#
# panicbutton
#
# TravelHungry
#
# GarrettMarc
#
# BEL123
#
# LSW26
#
# texasmom13
#
# Vornadito
#
# CloudyDae
#
# Dupra
#
# Whoozer
#
# Laughguard
#
# fdom
#
# jwb3rx
#
# dsklar
#
# julie078
#
# Reactor1966
#
# madge21
#
# John066
#
# mudhen1
#
# pietrobcn
#
# SyndiQ321
#
# A567
#
# kmizah
#
# pitbulls
#
# Lvega718
#
# chriske5
#
# PolarBears
#
# kuiarra
#
# Webgemgamer22
#
# colsterNyc
#
# medfordpoker
#
# EdithWharto
#
# Goldie111
#
# arohm
#
# Simplycuban
#
# jayh-7
#
# BFPW
#
# neutrino
#
# baskin
#
# Sampras
#
# Zwithapggb
#
# Meguelito
#
# KarlaG.
#
# edjob210
#
# MCLee
#
# BostonFamily2024
#
# GlBo7
#
# malm
#
# wineluver
#
# icunurse
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# wilcoam
#
# Showsheena
#
# answergirl
#
# MBG13
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# restlesstraveler
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# toothsleuth
#
# fcsmom
#
# A TripAdvisor Member
#
# overniteTPE
#
# A TripAdvisor Member
#
# BeckyandMike
#
# NewYork_NYMoso
#
# tamiris
#
# Shilpav
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# Princess_Mom
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# artsguy48
#
# spartaninpr
#
# A TripAdvisor Member
#
# zhuoen
#
# Kurosaki
#
# codash
#
# Scooper80
#
# SydneySally
#
# tamasutra65
#
# bax52
#
# Tucson_AZBella
#
# bellasusanna
#
# prycehudson
#
# YorkTravelGirl
#
# tonymus
#
# 9Catz
#
# bex9338
#
# VeronicaWashingtonDC
#
# TheAdmiralNelson
#
# melrod26
#
# Archipelagic
#
# SusieQ78
#
# EDMONTONSANDY
#
# cortney
#
# TracyJG
#
# Purn
#
# odanao
#
# bkimberly
#
# karmaghost
#
# JCashMoney
#
# Marna
#
# Acipenser
#
# brianpre
#
# travelexpertglobe
#
# 7johnny
#
# JGFMLF
#
# tc_kmc
#
# erinwyher
#
# bes166
#
# Rayamajhi
#
# ATLesquire
#
# readingmichael
#
# Echosphere
#
# KBSilverSpring
#
# batesy16
#
# ciana90Sheffield
#
# cfw33
#
# WaterBridgeRich
#
# style_uncompromised
#
# 606zpx
#
# Grizzy
#
# elchavo
#
# faura
#
# T. Advisor King
#
# skijazman
#
# MallardDrake
#
# Ottawagal62
#
# MugsMags
#
# corevel
#
# KingH
#
# JennyJoline
#
# 3marmots
#
# Tinnpusher
#
# happytwinsmom
#
# zumpie
#
# Belasaria
#
# SD_based
#
# ginbot
#
# bghky
#
# TonyCi
#
# berrribabe
#
# leahschatz
#
# Bliss_Blister
#
# Donnabubble
#
# borstalboy
#
# travelCleveland_OH
#
# Seanie1
#
# tripperjj
#
# KingPaul
#
# lisabellab
#
# kawh
#
# Camille350
#
# cgstine33
#
# agentlei
#
# lIdwi
#
# SeattleTraveler88
#
# markusinmiami
#
# spider85
#
# Collegecornerback
#
# LookitsJessica
#
# LML4400
#
# travelfreak2007
#
# frangipani7
#
# xp01321
#
# cristianonyc
#
# AEC in SF
#
# graceb1980
#
# lexycal
#
# KM37
#
# vadajo
#
# auntiecoco
#
# stonesc
#
# KMS157
#
# ss77
#
# travelgrrlnyc
#
# tintz
#
# julie1294
#
# bmacbc
#
# Jo-travel-alot
#
# magrinds
#
# dephal
#
# TravelsWithFriday
#
# sunchaser576
#
# sanfranmanPhoenix_Az
#
# grove911
#
# t_rose72
#
# Rifle762
#
# Retired1811
#
# Jemmag
#
# JULOfrVan
#
# ZipsnBucks
#
# haqansar
#
# frequent_fam_travel
#
# moodysgoose
#
# superstardj
#
# irishhud
#
# avidTrav3ller
#
# the-rach
#
# UofLFan
#
# wcswing158
#
# SanAntonioTXtravel
#
# wvu22
#
# cayucosqueen
#
# TattersallSacramento
#
# voreezz73
#
# at900
#
# CAtraveler87
#
# essojb
#
# 650golfer
#
# JudiAustralia
#
# sueeMaryland
#
# Bostontravlr
#
# LovesTheMountains
#
# bsb616
#
# tillmans
#
# OhioChowhound
#
# kiwijoy
#
# takedown8
#
# brindare
#
# aarcher
#
# nevers
#
# a.p.1017
#
# writewhatyouknow
#
# larsthorwald
#
# frosty0607
#
# dairydavid
#
# Steffenino
#
# SanDiegoAdventurer
#
# eatonl
#
# LovesTheCity
#
# sidneyeffing
#
# simonDublinIreland
#
# TxTravelPro
#
# wategos
#
# jenCALI
#
# Member3
#
# innkeepmendo
#
# Jen1985
#
# saltspringislander
#
# LAguy2000
#
# seeddh
#
# keyze
#
# MardiWalker
#
# fire_chick_4_life
#
# DanielRonfeld
#
# bcfcfan
#
# Brotsy
#
# renotrvlr
#
# nvraiderfan
#
# ChicagoGuy68
#
# Ursus62
#
# David&Kim
#
# kimberli9
#
# Reeskers
#
# Academic_Excellence
#
# Occasional-visitor
#
# pa05
#
# bklver
#
# terriraven
#
# Miss-Traveller
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# Disappointed73
#
# A TripAdvisor Member
#
# firsttimeinvegas
#
# gsaz
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# katecookey
#
# A TripAdvisor Member
#
# giadas
#
# Bulldawg
#
# imjimsharp
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# Eric_C_W
#
# A TripAdvisor Member
#
# eddiefromsuckramento
#
# A TripAdvisor Member
#
# ucantimagine
#
# Frogwell
#
# vaznayak
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# SusieLou
#
# marinaahmad
#
# A TripAdvisor Member
#
# dbuster
#
# drimbane
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# micdenver
#
# A TripAdvisor Member
#
# bluejava2
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# Smoke_Joyce
#
# lass=
#
# Gabri69
#
# lass=
#
# leprotta
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# davidtgn
#
# gregory76
#
# lass=
#
# lass=
#
# lass=
#
# derglobetrotter
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# agalwaygirl
#
# stupidscreenname95
#
# JonBarretto
#
# dudeh
#
# Biyp
#
# KeepDiscovering
#
# jdelor
#
# JohnP099
#
# BXG824
#
# lolafefe
#
# LsBob
#
# JayneAustralia
#
# Gunya
#
# butlerrobj
#
# working_dadPI
#
# travelexpress
#
# knarfHonolulu
#
# SinghP
#
# marcimarc444
#
# waysideNewYork
#
# ahallnz
#
# greatvoyager
#
# RainmanMumbai
#
# DavaoEagles
#
# PhilippZ
#
# Doodstar
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# ilovetoshop
#
# A TripAdvisor Member
#
# A TripAdvisor Member
#
# danairozo
#
# pglohan
#
# hig313
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=
#
# lass=

# %%
user2review.keys()
# Out:
# dict_keys([''])

# %%
user_aspect_dict = pickle.load(open('../dataset/TripAdvisor/user_aspect_dict.pickle', 'rb'))

# %%
user_aspect_dict
# Out:
# {'RuckOU': [0, 1, 1, 0, 0, 0, 0, 0],
#  'genluxx': [1, 0, 1, 1, 0, 0, 1, 0],
#  'honestmum': [0, 0, 1, 0, 0, 0, 0, 0],
#  'Traveller28London': [1, 0, 0, 1, 0, 0, 0, 0],
#  'DenverWing': [1, 1, 1, 1, 0, 0, 1, 0],
#  'MidwestBizzyTraveler': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Louis13': [1, 0, 0, 1, 0, 1, 1, 0],
#  'Rob0ny': [0, 1, 1, 1, 0, 1, 1, 0],
#  'Aussies88': [1, 1, 1, 1, 0, 1, 1, 0],
#  'lizzyb2': [1, 1, 1, 1, 0, 0, 1, 0],
#  'rvh0111': [1, 1, 1, 1, 0, 0, 0, 0],
#  'Sequin-Sue': [1, 1, 1, 1, 0, 1, 1, 0],
#  'NickSJ': [1, 0, 1, 0, 0, 0, 0, 0],
#  'Captain_Weasel': [1, 0, 1, 1, 0, 1, 1, 0],
#  'tellsitlikeitisSpain': [1, 1, 1, 1, 0, 1, 1, 0],
#  'australian_8': [1, 1, 1, 0, 0, 0, 1, 0],
#  'MaYBaBeOSU13': [1, 1, 1, 1, 1, 0, 1, 0],
#  'rocketman1957': [1, 0, 0, 0, 0, 0, 0, 0],
#  'heaven911': [1, 1, 1, 1, 0, 1, 1, 0],
#  'gandgturner': [0, 0, 1, 0, 0, 0, 0, 0],
#  'theschmidthouse': [1, 0, 1, 0, 0, 1, 0, 0],
#  'luv2trvl007': [1, 1, 1, 1, 0, 0, 0, 0],
#  'hmarsh8': [1, 1, 1, 0, 1, 1, 1, 0],
#  'Penelope_Keith': [1, 1, 1, 1, 0, 0, 1, 1],
#  'LittleMissShiny': [1, 1, 1, 1, 0, 1, 1, 0],
#  'ljubalassala': [1, 0, 0, 1, 0, 0, 0, 1],
#  'neal1260': [1, 1, 1, 1, 0, 0, 0, 0],
#  'chop76': [1, 0, 1, 0, 1, 1, 1, 0],
#  'sleepymiami': [1, 0, 1, 1, 0, 0, 1, 0],
#  'SF0811': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Lugageboy': [0, 1, 1, 1, 0, 1, 1, 0],
#  'devanisha2905': [1, 0, 1, 0, 1, 1, 0, 0],
#  'PipBristol': [0, 1, 1, 0, 0, 1, 0, 0],
#  'Osupartygrl': [1, 1, 1, 1, 0, 1, 1, 0],
#  'RetrieversDad': [1, 1, 1, 1, 0, 1, 0, 0],
#  'floirdagreat': [1, 1, 0, 1, 0, 0, 1, 0],
#  'nyc_kosta': [1, 1, 1, 1, 1, 1, 1, 0],
#  'Rach-n-SD': [0, 0, 1, 0, 0, 0, 1, 0],
#  'SoCalGirl2': [1, 1, 1, 0, 0, 1, 1, 0],
#  'JLuv033': [1, 1, 1, 0, 1, 0, 1, 0],
#  'jenialexis': [1, 1, 1, 1, 1, 1, 1, 0],
#  'woolloomoolo': [0, 1, 1, 1, 0, 0, 1, 0],
#  'travelgirlkk': [1, 1, 1, 1, 0, 1, 1, 0],
#  'vanessam': [1, 1, 1, 1, 0, 1, 1, 0],
#  'thepurple_monkey': [1, 0, 1, 1, 0, 1, 1, 0],
#  'juckett': [1, 1, 1, 1, 0, 0, 1, 0],
#  'EiriniAustralia_': [1, 1, 1, 1, 0, 1, 1, 0],
#  'missynmark': [1, 1, 1, 1, 0, 1, 1, 0],
#  'RusedatRoosevelt': [1, 1, 0, 0, 0, 1, 1, 0],
#  'Margaritaville11': [0, 1, 1, 1, 0, 1, 1, 0],
#  'Thetravelers45': [1, 1, 1, 1, 0, 1, 0, 0],
#  'prockbirdman': [1, 0, 0, 1, 0, 0, 0, 0],
#  'colin-leeds': [0, 0, 1, 0, 0, 0, 0, 0],
#  'MexicoAnaMaria': [1, 0, 0, 1, 0, 0, 0, 0],
#  'jorrit9': [1, 1, 0, 0, 0, 0, 1, 0],
#  'jknecole': [1, 0, 0, 0, 0, 0, 0, 0],
#  'lork': [1, 0, 1, 1, 0, 1, 1, 0],
#  'tea_addict': [1, 1, 1, 1, 0, 0, 1, 0],
#  'ValerieMow': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Camberleybob': [1, 1, 1, 1, 0, 0, 1, 0],
#  'LondonJetSetters': [1, 1, 1, 1, 0, 0, 0, 0],
#  'isee1': [1, 1, 1, 1, 1, 1, 1, 0],
#  'bonnyparker': [0, 1, 0, 0, 0, 0, 0, 0],
#  'BobAdams111': [1, 1, 1, 1, 0, 1, 1, 0],
#  'fly4fun2': [1, 0, 1, 1, 0, 0, 1, 1],
#  'roberta_nyc': [1, 1, 1, 1, 1, 1, 1, 1],
#  'edo408': [1, 1, 1, 1, 0, 1, 0, 0],
#  'CheekyAngel': [0, 0, 1, 1, 0, 0, 1, 0],
#  'tanja39': [1, 1, 0, 1, 0, 0, 0, 0],
#  'coolgirlz1': [1, 0, 1, 0, 0, 1, 0, 0],
#  'bjpeart': [1, 1, 1, 0, 0, 1, 1, 0],
#  'bratty3000': [1, 1, 1, 1, 0, 1, 1, 0],
#  'caligirl111': [1, 1, 1, 1, 0, 1, 0, 0],
#  'OCCouple2004': [1, 0, 1, 1, 0, 1, 1, 0],
#  'ChrisLondon_UK': [1, 1, 1, 1, 0, 1, 1, 0],
#  'KBTwinCities': [1, 0, 1, 0, 0, 1, 1, 0],
#  'wanthelp': [1, 0, 0, 1, 0, 0, 1, 0],
#  'TwoHavlesofCoconuts': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Trippers123': [1, 1, 1, 1, 0, 1, 1, 1],
#  'sunny_ksgirl': [1, 0, 1, 1, 0, 1, 1, 0],
#  'BHA1': [1, 1, 1, 0, 0, 1, 1, 0],
#  'juliaridgeley': [1, 0, 1, 0, 0, 1, 0, 0],
#  'citygirl001': [1, 1, 0, 1, 0, 1, 1, 0],
#  'jsdCalifornia': [1, 1, 1, 1, 0, 1, 1, 0],
#  'SoCalCanucks': [0, 0, 1, 0, 0, 0, 1, 0],
#  'havanahipster': [1, 1, 1, 1, 0, 1, 1, 1],
#  'starstatus': [1, 1, 1, 0, 0, 1, 1, 1],
#  'sdht': [1, 0, 1, 1, 0, 0, 1, 1],
#  'jamsgurl': [1, 1, 1, 0, 0, 0, 1, 0],
#  'tim1966': [1, 1, 1, 1, 0, 1, 1, 0],
#  'LVNative50': [1, 0, 1, 1, 1, 0, 1, 0],
#  'PegLar': [1, 1, 1, 1, 0, 1, 1, 0],
#  'mamababoo': [1, 1, 1, 0, 1, 1, 1, 0],
#  'lboasis': [1, 0, 1, 1, 0, 1, 0, 0],
#  'fun4uinbshore': [1, 1, 1, 1, 0, 1, 1, 1],
#  'anyasall': [1, 1, 1, 0, 0, 1, 1, 0],
#  'gordongecko45': [1, 1, 1, 0, 0, 0, 1, 0],
#  'annekr': [1, 1, 1, 1, 1, 1, 1, 1],
#  'giraffesinspace': [1, 1, 1, 1, 0, 0, 1, 0],
#  'natalieb271': [1, 1, 1, 1, 0, 1, 1, 0],
#  'techsan04': [0, 0, 1, 0, 0, 0, 0, 0],
#  'geribeau': [1, 1, 1, 0, 0, 0, 1, 0],
#  'DublA': [1, 1, 1, 0, 0, 1, 1, 0],
#  'Jahney': [1, 1, 1, 0, 1, 0, 1, 0],
#  'Elysium73': [1, 1, 1, 1, 0, 1, 1, 0],
#  'GreatDaneDanmark': [1, 1, 1, 1, 0, 0, 0, 0],
#  'trvlgrlLosAngeles': [1, 0, 0, 0, 0, 1, 1, 0],
#  'hellolizzie3': [1, 0, 1, 0, 1, 1, 1, 0],
#  'bleeee': [1, 0, 1, 0, 0, 1, 1, 0],
#  'PopArtist': [0, 0, 1, 0, 0, 0, 0, 0],
#  'LasVegasFan007': [1, 1, 1, 1, 0, 1, 1, 0],
#  'SFGuy35': [1, 1, 1, 1, 0, 1, 1, 1],
#  'emablair': [1, 0, 1, 1, 0, 1, 1, 0],
#  'truprunbike': [1, 1, 1, 1, 1, 1, 1, 0],
#  'NYSpiffy': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Angelina628': [1, 0, 1, 0, 0, 1, 1, 0],
#  'thinklinz': [1, 1, 0, 1, 0, 1, 0, 0],
#  'dahliablue': [1, 1, 1, 0, 0, 0, 1, 0],
#  'MillerCorona': [1, 1, 1, 1, 1, 1, 1, 1],
#  'sunline': [1, 1, 1, 0, 0, 1, 0, 0],
#  'SignorSummer': [1, 1, 1, 1, 0, 1, 0, 1],
#  'jetlagnow': [1, 1, 1, 1, 0, 0, 1, 0],
#  'ebowen': [1, 1, 1, 0, 0, 1, 1, 0],
#  'AustraliaSheba': [1, 1, 1, 1, 0, 1, 1, 0],
#  'mrwolfinca': [1, 1, 1, 1, 0, 0, 1, 0],
#  'coolchickie76': [1, 1, 1, 1, 0, 1, 1, 1],
#  'StephanieCincinnati': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Edsco': [1, 1, 1, 0, 0, 1, 1, 0],
#  'rsq': [1, 0, 1, 1, 0, 1, 0, 0],
#  'flygirl1304': [0, 1, 1, 1, 0, 1, 0, 0],
#  'FreddieBSeattle': [1, 0, 1, 1, 0, 1, 1, 0],
#  'aostevenson': [1, 1, 1, 0, 0, 1, 0, 0],
#  'shellmjb': [1, 1, 1, 1, 0, 1, 1, 0],
#  'emmalouise76': [1, 1, 1, 0, 0, 1, 0, 0],
#  'MutleyDog': [1, 1, 1, 1, 0, 1, 1, 0],
#  'mf90210': [1, 1, 1, 1, 0, 1, 1, 1],
#  'bryncellen': [0, 1, 1, 0, 0, 0, 0, 0],
#  'Sailsand': [1, 1, 1, 0, 0, 0, 1, 0],
#  'nytro1': [1, 1, 1, 1, 0, 0, 1, 0],
#  'jeckle': [1, 1, 1, 1, 0, 1, 1, 0],
#  'roo15': [1, 1, 1, 0, 0, 1, 1, 0],
#  'waskom2': [1, 0, 1, 1, 0, 1, 0, 0],
#  'bryzo': [1, 0, 0, 0, 0, 0, 0, 0],
#  'glamourpuss1000': [1, 1, 1, 1, 0, 1, 1, 0],
#  'soleil17': [1, 1, 1, 1, 0, 1, 1, 1],
#  'fatboyonadiet': [1, 1, 1, 1, 0, 1, 1, 0],
#  'shourick': [1, 0, 1, 0, 0, 0, 0, 0],
#  'MsLaurie': [1, 1, 1, 1, 0, 1, 1, 1],
#  'larneman': [0, 0, 1, 0, 0, 0, 1, 0],
#  '2006travel': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Donohill': [1, 0, 1, 1, 0, 1, 0, 0],
#  'howarth': [1, 1, 1, 0, 1, 1, 1, 1],
#  'Michellin5star': [0, 1, 0, 0, 0, 1, 1, 0],
#  'jupio23': [1, 0, 1, 0, 0, 0, 0, 0],
#  'needavaykay': [1, 1, 1, 1, 0, 1, 1, 0],
#  'CaBusinessTraveler': [1, 0, 1, 1, 0, 1, 1, 0],
#  'www.teamblackout.net': [1, 0, 0, 0, 0, 0, 0, 0],
#  'KTESJE': [1, 0, 1, 1, 0, 0, 0, 0],
#  'redinsf': [1, 1, 1, 1, 0, 0, 0, 0],
#  'MikeGeee': [1, 1, 1, 1, 1, 1, 1, 0],
#  'Hilaire': [1, 1, 1, 1, 0, 1, 1, 0],
#  'PURP': [1, 1, 1, 0, 0, 1, 1, 0],
#  'sayheytk': [1, 1, 1, 0, 0, 1, 1, 0],
#  'MTNZLONDON': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Chachagal': [1, 0, 0, 0, 0, 0, 0, 0],
#  'lagunadallas': [1, 1, 1, 1, 0, 0, 1, 0],
#  'davsyd': [1, 1, 1, 1, 1, 1, 1, 0],
#  'A TripAdvisor Member': [1, 1, 1, 1, 1, 1, 1, 1],
#  'johngie': [1, 0, 1, 0, 0, 1, 0, 0],
#  'AvantGarden': [1, 0, 1, 1, 1, 1, 1, 0],
#  'Jkknoonan': [1, 1, 1, 1, 0, 1, 1, 0],
#  'bodijeep75': [1, 0, 0, 0, 0, 0, 0, 0],
#  'Atturnbull': [1, 0, 0, 0, 0, 0, 0, 0],
#  'choward1': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Jake029': [1, 0, 1, 1, 0, 0, 0, 0],
#  'Ira619': [1, 1, 1, 0, 0, 1, 1, 1],
#  'magdonnelly': [1, 1, 1, 1, 0, 1, 1, 0],
#  'mr_mactee': [1, 1, 1, 1, 1, 1, 1, 0],
#  'misslinda00': [1, 1, 1, 0, 0, 0, 1, 0],
#  'B-ram-z': [1, 0, 1, 1, 1, 0, 1, 1],
#  'jano1932': [1, 1, 1, 1, 0, 1, 1, 1],
#  'MarriedGG': [1, 1, 1, 0, 0, 0, 1, 0],
#  'kumidog': [1, 1, 1, 1, 0, 1, 1, 0],
#  'kane020': [1, 0, 1, 1, 0, 1, 1, 0],
#  'vacationfromchgo': [1, 1, 1, 1, 0, 1, 1, 0],
#  'devinevacation': [1, 1, 1, 0, 0, 0, 1, 0],
#  'LambyHibs': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Cambridge_Family': [1, 1, 1, 1, 0, 1, 1, 0],
#  'titanik': [1, 0, 1, 1, 0, 1, 1, 0],
#  'jkeyser': [1, 1, 1, 1, 0, 1, 0, 1],
#  'SFsister': [1, 0, 1, 1, 0, 1, 1, 0],
#  'flasugmag': [1, 1, 1, 1, 0, 1, 1, 0],
#  'ECTB': [0, 0, 0, 1, 0, 0, 0, 0],
#  'barb600': [1, 0, 1, 1, 0, 1, 0, 0],
#  'tjh17': [1, 1, 1, 1, 0, 1, 1, 0],
#  'kasialouise': [0, 0, 1, 0, 0, 0, 0, 0],
#  'australiantraveller': [1, 0, 1, 1, 0, 1, 0, 0],
#  'notgoth': [1, 1, 1, 1, 0, 1, 1, 0],
#  'DutchyCan': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Saffy2': [1, 1, 1, 1, 0, 1, 1, 1],
#  'nick47': [1, 0, 1, 1, 0, 0, 1, 0],
#  'staceysteve99': [1, 0, 1, 1, 0, 0, 1, 0],
#  'politicsdc': [1, 0, 1, 1, 0, 1, 0, 0],
#  'dat1123': [1, 1, 1, 1, 0, 1, 0, 0],
#  'MKeebler': [1, 0, 1, 1, 1, 0, 0, 0],
#  'Synchronicity': [1, 0, 1, 1, 0, 0, 0, 0],
#  'SunnyC': [1, 1, 1, 1, 0, 1, 1, 1],
#  'topcat72': [1, 1, 1, 0, 0, 1, 1, 0],
#  'Qld Girl': [0, 1, 1, 1, 0, 1, 0, 0],
#  'sallybjo': [1, 0, 1, 1, 1, 0, 1, 0],
#  'ReedyBarnsley': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Marcus_and_Wendy': [1, 1, 1, 1, 1, 1, 1, 0],
#  'iluvla': [1, 1, 1, 1, 0, 1, 1, 0],
#  'svbur': [1, 0, 1, 1, 0, 1, 0, 0],
#  'cjennt': [1, 1, 1, 1, 1, 1, 1, 0],
#  'JACKIEMCCANDLESS': [1, 0, 1, 1, 0, 1, 0, 0],
#  'CatPaw7': [1, 1, 1, 0, 0, 1, 0, 0],
#  'DoNotDisturb': [1, 1, 1, 1, 0, 0, 0, 0],
#  'North_Wales_Lass': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Likeness': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Meursault': [1, 1, 1, 1, 1, 1, 1, 0],
#  'jetset05': [1, 1, 1, 1, 0, 0, 0, 0],
#  'tm1978': [1, 1, 1, 1, 0, 0, 0, 0],
#  'Samsie': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Dutchbairn': [1, 1, 1, 1, 1, 1, 0, 1],
#  'saperlip0pette': [1, 0, 0, 0, 0, 0, 0, 0],
#  'morvezen': [1, 0, 0, 0, 0, 0, 1, 0],
#  'LAUNDRYCOTTAGES': [0, 1, 1, 1, 1, 1, 1, 0],
#  'Reilly7': [1, 1, 1, 1, 0, 1, 1, 0],
#  'liketotraveldc': [1, 1, 1, 1, 1, 1, 1, 0],
#  'JamesVki': [1, 1, 1, 1, 0, 1, 1, 0],
#  'laddoePerthWa': [1, 0, 1, 1, 0, 0, 1, 0],
#  'Fevery': [1, 0, 1, 1, 0, 0, 1, 1],
#  'Plantie': [1, 0, 0, 0, 0, 0, 0, 0],
#  'liandra7': [1, 0, 1, 1, 0, 0, 1, 0],
#  'MoulayMorocco': [1, 1, 1, 1, 0, 1, 0, 1],
#  'JakartaMember': [1, 1, 1, 1, 1, 1, 1, 1],
#  'Ray26': [1, 0, 0, 0, 0, 0, 0, 0],
#  'M.P....Abbotsford': [1, 0, 1, 0, 0, 1, 1, 0],
#  'baliselalu': [1, 0, 0, 0, 0, 0, 0, 0],
#  'wilsonjenny': [1, 0, 1, 0, 0, 0, 0, 0],
#  'hibachi': [1, 1, 1, 1, 1, 1, 1, 1],
#  'lucksta': [1, 1, 1, 1, 0, 1, 1, 0],
#  'iBike': [1, 0, 1, 1, 1, 0, 1, 0],
#  'RobMichelle': [1, 1, 1, 1, 0, 1, 0, 0],
#  'TriciaMc': [1, 0, 1, 1, 0, 0, 1, 0],
#  'Impishjalla': [1, 0, 1, 1, 0, 1, 0, 0],
#  'kruizerkarol': [1, 1, 1, 1, 1, 1, 1, 1],
#  'chitownflyfisher': [1, 0, 0, 1, 0, 0, 0, 0],
#  'podoho': [1, 1, 1, 1, 0, 1, 1, 0],
#  'njrunr3': [1, 1, 1, 0, 0, 1, 1, 1],
#  'LMomNY': [1, 0, 1, 1, 0, 0, 1, 1],
#  'MrBunny': [1, 1, 1, 1, 0, 1, 1, 0],
#  'SPaPP': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Danielle75': [0, 0, 1, 0, 0, 0, 0, 0],
#  'Scout44': [1, 1, 1, 1, 0, 1, 1, 1],
#  'travelfan10706': [1, 1, 1, 0, 0, 1, 0, 0],
#  "Isle 'n Sun": [1, 1, 1, 1, 0, 1, 1, 0],
#  'ArizonaGrandparents': [1, 1, 1, 1, 0, 1, 0, 1],
#  'RebeccaZ': [1, 1, 1, 1, 0, 0, 0, 1],
#  'CoCoSandy': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Charyty': [1, 1, 1, 1, 0, 0, 1, 0],
#  'tampabobl': [1, 0, 1, 1, 0, 1, 1, 0],
#  'TripAdviceTucson': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Derrico': [1, 1, 1, 1, 0, 1, 0, 1],
#  'NMtravelertoo': [1, 1, 1, 1, 0, 1, 1, 0],
#  'grcas': [1, 1, 1, 1, 1, 1, 1, 0],
#  'beachmiker': [1, 0, 1, 0, 0, 1, 1, 0],
#  'Masonpips': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Homergirl': [1, 1, 1, 0, 1, 1, 1, 1],
#  'BocaBlocks': [0, 0, 1, 1, 0, 1, 1, 1],
#  'Mezlin': [1, 1, 1, 1, 0, 1, 0, 0],
#  'CathySEdmondsWA': [1, 1, 1, 0, 0, 0, 1, 0],
#  'sweetdreams0703': [1, 0, 1, 1, 0, 1, 0, 0],
#  'maystamper': [1, 1, 1, 1, 1, 0, 1, 0],
#  'DianeKathleen': [1, 0, 1, 1, 0, 0, 0, 0],
#  'GarethClayton': [1, 0, 1, 1, 0, 0, 1, 0],
#  'realfan112': [0, 0, 1, 1, 0, 1, 0, 0],
#  'brokenbranches79': [0, 1, 1, 1, 0, 0, 1, 0],
#  'Thingsbgrindin': [0, 0, 1, 0, 0, 0, 0, 0],
#  'michaeljasongray': [1, 0, 1, 1, 0, 0, 1, 0],
#  'IloveNY_2007': [1, 0, 1, 1, 0, 1, 1, 0],
#  'swtraveler2': [1, 1, 1, 1, 0, 1, 0, 0],
#  'JenIttels': [0, 0, 1, 0, 0, 0, 0, 0],
#  'docozoo': [1, 1, 1, 1, 0, 1, 1, 0],
#  'm1zetern1ty': [1, 1, 1, 0, 1, 0, 0, 0],
#  'CKCVancouver': [1, 1, 1, 1, 0, 1, 0, 0],
#  'mybrainhurts': [1, 1, 0, 1, 0, 0, 0, 1],
#  'Whismerhill': [1, 0, 1, 0, 0, 0, 0, 0],
#  'Mark76': [0, 1, 0, 0, 0, 0, 0, 0],
#  'GijonClarke': [0, 1, 0, 1, 1, 0, 0, 0],
#  'cnspostma': [1, 0, 1, 1, 1, 0, 1, 0],
#  'zophie100': [1, 0, 1, 0, 0, 1, 0, 0],
#  'madelynium': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Kathy_Houtami': [0, 0, 1, 0, 0, 0, 0, 0],
#  'WilliamHo': [1, 0, 1, 1, 0, 0, 0, 0],
#  'mechemist': [0, 1, 1, 1, 0, 0, 1, 0],
#  'coffeepot/NJ': [0, 1, 1, 1, 0, 0, 0, 0],
#  'beemac70': [1, 1, 0, 1, 0, 1, 0, 0],
#  'JSLAJ': [1, 0, 1, 1, 1, 0, 0, 0],
#  'MelnJay': [0, 1, 1, 1, 0, 0, 1, 0],
#  'Skewlio': [1, 0, 1, 1, 0, 1, 0, 0],
#  'UK_Traveller3000': [1, 0, 1, 1, 1, 1, 1, 1],
#  'Racers': [0, 1, 1, 1, 0, 1, 1, 0],
#  'lfc84': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Grandpa_Travels': [1, 0, 1, 1, 0, 0, 1, 0],
#  'allstar919': [1, 1, 1, 1, 0, 1, 0, 0],
#  'trave': [1, 1, 1, 1, 0, 1, 1, 0],
#  'groquick': [1, 0, 0, 0, 0, 0, 0, 0],
#  'vepvip': [0, 0, 1, 1, 0, 1, 1, 0],
#  'Gertrude73': [1, 0, 1, 0, 0, 1, 1, 0],
#  'musedir': [1, 0, 1, 1, 1, 0, 1, 0],
#  'momo58California': [1, 0, 0, 0, 0, 1, 0, 0],
#  'KimKBigFlats_NY': [0, 0, 1, 0, 0, 1, 0, 0],
#  'thenoddlers': [0, 1, 1, 1, 0, 1, 0, 0],
#  'Idlewildmemories': [1, 1, 1, 1, 0, 0, 1, 0],
#  'SamanthainNJ': [1, 1, 1, 1, 0, 1, 0, 0],
#  'KRRI': [1, 0, 0, 0, 0, 0, 1, 0],
#  'XComsGirl': [1, 0, 1, 1, 0, 1, 1, 0],
#  'califanglophile': [1, 1, 1, 1, 0, 0, 1, 0],
#  'bagueili': [0, 0, 1, 1, 0, 1, 1, 0],
#  'Pauldundalkireland': [1, 1, 0, 1, 0, 1, 1, 0],
#  'dallastraveler29': [0, 0, 1, 0, 0, 0, 0, 0],
#  'OntheR0ad08': [1, 1, 1, 0, 0, 0, 0, 0],
#  'MarieM_7': [1, 0, 1, 0, 0, 1, 0, 0],
#  'emijon': [1, 0, 1, 1, 0, 0, 1, 1],
#  'Sicilybound': [1, 0, 1, 1, 0, 1, 1, 0],
#  'naynayOpKs': [1, 0, 1, 0, 0, 1, 1, 0],
#  'Trips_MEP': [1, 0, 0, 1, 0, 0, 1, 0],
#  'Lovetotravelitaly': [1, 1, 1, 1, 0, 1, 1, 0],
#  'alex3485': [0, 0, 1, 1, 0, 0, 1, 0],
#  'dbrallmann': [1, 1, 1, 1, 0, 1, 1, 1],
#  'JANDGW': [1, 1, 1, 0, 0, 1, 1, 0],
#  'CalgaryMomma': [1, 0, 1, 1, 0, 1, 1, 0],
#  'DonWondemarko': [1, 1, 1, 1, 0, 1, 1, 0],
#  'bghb514': [1, 1, 0, 1, 0, 1, 1, 0],
#  'tbabbitt': [1, 0, 0, 1, 0, 0, 1, 0],
#  'METenthusiast': [1, 0, 1, 1, 0, 1, 0, 0],
#  'prairieschooner': [1, 1, 1, 1, 0, 0, 1, 0],
#  'lynnepev': [1, 1, 1, 1, 0, 0, 1, 0],
#  'SIEDW': [0, 0, 1, 0, 0, 1, 0, 1],
#  'TandLtravels': [0, 0, 1, 1, 0, 0, 1, 0],
#  'justwanderlust': [1, 1, 1, 0, 1, 1, 0, 0],
#  'Manhattan2008': [1, 1, 0, 1, 0, 0, 1, 0],
#  'Fitz7': [1, 0, 1, 0, 0, 1, 1, 0],
#  'CloeNorthVancouver': [1, 0, 1, 1, 0, 0, 0, 0],
#  'ElectraSeCT': [1, 0, 1, 0, 0, 0, 1, 1],
#  'Copprjack': [0, 1, 1, 1, 0, 1, 1, 0],
#  'TAMemberSanJose_CA': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Dee049': [1, 0, 1, 1, 0, 1, 1, 0],
#  'TexasSATraveler': [1, 1, 1, 1, 0, 1, 1, 1],
#  'KatoMate': [1, 0, 1, 0, 0, 1, 0, 0],
#  'marcopollo2008': [1, 0, 1, 1, 0, 0, 1, 0],
#  'ValueHunterToronto': [1, 0, 0, 1, 0, 0, 0, 0],
#  'MicheleWatauga_TX': [1, 0, 1, 1, 0, 0, 0, 1],
#  'PollyV': [1, 0, 1, 0, 0, 0, 0, 0],
#  'Laura_Neil': [1, 1, 1, 1, 0, 1, 1, 0],
#  'happytravelers025': [1, 1, 1, 1, 0, 0, 1, 0],
#  'karenbeyke': [1, 0, 1, 0, 0, 0, 0, 0],
#  'Californiadreamer608': [1, 0, 1, 1, 0, 1, 1, 0],
#  'CAMMassachusetts': [1, 0, 0, 1, 0, 0, 1, 0],
#  'mklement': [1, 0, 1, 1, 0, 0, 0, 0],
#  'pattywahl': [1, 1, 1, 0, 0, 1, 1, 0],
#  'lovetravelerreviews': [1, 0, 1, 1, 0, 1, 1, 0],
#  'travellingDoc27': [1, 0, 1, 1, 0, 0, 1, 0],
#  'ronelaine': [1, 1, 1, 1, 0, 1, 0, 0],
#  'bajanwoman': [1, 0, 1, 1, 0, 1, 1, 0],
#  'hamrlik44': [1, 0, 1, 1, 0, 1, 0, 0],
#  'ATLTEACHER': [0, 1, 1, 1, 0, 1, 1, 1],
#  'greatfulltraveler': [1, 0, 1, 1, 0, 1, 1, 0],
#  'djhtraveler': [1, 1, 1, 1, 0, 1, 1, 1],
#  'neworleanstraveler55': [1, 1, 1, 0, 0, 0, 1, 0],
#  'happyjacob': [1, 0, 0, 1, 0, 1, 0, 0],
#  'lillygitl': [1, 1, 1, 1, 0, 0, 0, 0],
#  'tutones': [1, 0, 1, 1, 0, 0, 1, 0],
#  'GHKhoo': [1, 0, 0, 0, 0, 1, 1, 0],
#  'Dr4nsix': [1, 0, 1, 1, 0, 0, 1, 0],
#  'meg433': [1, 0, 0, 1, 0, 0, 0, 0],
#  'longandwindingroad': [1, 1, 1, 0, 0, 1, 0, 0],
#  'mombojack': [1, 0, 1, 0, 0, 1, 0, 0],
#  'smurf25': [1, 0, 1, 0, 0, 0, 1, 0],
#  'NashvilleMimi': [1, 0, 1, 1, 0, 1, 0, 0],
#  'Bryn_Mawr_Mpls': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Ricardfred': [1, 1, 1, 1, 0, 1, 1, 0],
#  'travelhappy111': [1, 0, 1, 1, 0, 1, 1, 0],
#  'finjr': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Isik': [1, 1, 0, 1, 0, 1, 1, 0],
#  'annswolter': [1, 0, 1, 1, 0, 1, 1, 0],
#  'labm': [0, 1, 1, 1, 0, 1, 0, 0],
#  'nonamesforme': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Italiangirl01': [1, 1, 0, 1, 0, 1, 1, 0],
#  'jemima-puddleduck4': [1, 0, 1, 0, 0, 0, 1, 0],
#  'pdale': [1, 1, 1, 0, 0, 0, 1, 0],
#  'UCDSig': [1, 1, 1, 1, 0, 0, 1, 1],
#  'viaggio123': [1, 0, 1, 1, 0, 1, 1, 0],
#  'CanadaTravelbug': [1, 1, 0, 0, 0, 1, 1, 0],
#  'Shakespearephile': [0, 1, 1, 1, 0, 0, 1, 0],
#  'FreyaWoking': [1, 1, 1, 1, 0, 0, 1, 0],
#  'JKGodin': [1, 1, 1, 0, 0, 1, 0, 1],
#  'badgergirl01': [1, 0, 1, 1, 0, 1, 1, 0],
#  'NYhappy': [1, 0, 1, 0, 0, 1, 0, 0],
#  'BayAreaWorldTraveler': [1, 1, 1, 0, 1, 0, 1, 0],
#  'Coolmark': [1, 1, 1, 1, 0, 1, 1, 0],
#  'karen_gettman': [1, 1, 1, 0, 0, 1, 1, 0],
#  'KlemenLjubljana': [0, 0, 1, 1, 0, 0, 0, 0],
#  'TwoSybarites': [1, 0, 1, 1, 0, 0, 1, 0],
#  'CmeredithIII': [1, 1, 1, 1, 0, 1, 1, 1],
#  'witchipoo': [1, 1, 1, 0, 0, 1, 1, 0],
#  'RonInRomeo': [0, 1, 1, 0, 0, 1, 1, 0],
#  'ToddyLakeland_Fla': [0, 1, 1, 1, 0, 1, 1, 0],
#  'erasmushall': [0, 0, 0, 1, 0, 0, 1, 0],
#  'puilam': [1, 1, 1, 1, 0, 1, 1, 1],
#  'nickdodger': [1, 1, 1, 1, 0, 1, 1, 0],
#  'hmillerdoc': [1, 0, 0, 1, 0, 0, 1, 0],
#  'shdSussex': [1, 0, 1, 0, 0, 1, 0, 0],
#  'BestBeforeAyr': [1, 1, 1, 1, 0, 1, 1, 0],
#  'skyelite5352': [1, 0, 1, 0, 0, 1, 1, 0],
#  'TRAVELADY8': [1, 1, 1, 1, 0, 1, 1, 0],
#  'nytravels1000': [1, 0, 0, 1, 0, 1, 0, 0],
#  'nyctourist4u': [1, 1, 1, 1, 0, 1, 0, 0],
#  'GW1965': [1, 1, 1, 1, 0, 1, 0, 0],
#  'beckybb': [0, 1, 1, 0, 0, 0, 0, 0],
#  'Footlose6': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Ross01': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Lexington_KYPaula': [1, 0, 1, 1, 1, 1, 1, 0],
#  'Tiberious74': [1, 1, 1, 1, 0, 0, 0, 0],
#  'Monkspath-Taveller': [0, 1, 1, 0, 0, 0, 1, 0],
#  'irie_smile': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Jappal': [1, 0, 1, 1, 0, 1, 1, 0],
#  'amdgMd': [0, 0, 1, 0, 0, 1, 1, 0],
#  'melody_favish': [0, 0, 1, 1, 0, 0, 1, 0],
#  'tatume': [1, 0, 1, 1, 0, 1, 1, 0],
#  'swrglm': [1, 0, 1, 0, 0, 1, 1, 0],
#  'RobertMNZ': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Mizmilli': [1, 0, 1, 0, 0, 1, 1, 0],
#  'JunebugMedford_NJ': [1, 0, 0, 1, 0, 0, 1, 0],
#  'dkwojo': [1, 1, 1, 1, 0, 1, 0, 0],
#  'MallardDrake': [1, 0, 0, 1, 0, 1, 1, 0],
#  'NYC143': [1, 1, 1, 1, 1, 1, 1, 0],
#  'AandR': [0, 1, 1, 1, 0, 1, 1, 0],
#  'willSA': [1, 1, 1, 1, 0, 1, 1, 1],
#  'xnewyorker': [1, 0, 1, 1, 0, 1, 1, 1],
#  'forlilal': [1, 0, 0, 1, 0, 1, 1, 0],
#  'kathieann': [1, 1, 1, 1, 1, 1, 1, 0],
#  'Jemimagold': [1, 1, 1, 1, 1, 1, 1, 0],
#  'John-Kathleen': [1, 1, 1, 0, 0, 1, 1, 0],
#  'tcudarling': [1, 1, 1, 1, 0, 1, 1, 1],
#  'SarahLondon_UK': [1, 1, 1, 0, 0, 1, 1, 0],
#  'Fernix': [1, 1, 1, 1, 0, 0, 1, 0],
#  'sunvine': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Hen-nyTN': [1, 1, 1, 1, 0, 1, 1, 1],
#  'tandum': [1, 0, 1, 1, 0, 1, 1, 0],
#  'zoniac': [1, 0, 1, 1, 0, 0, 0, 1],
#  'jcjanec': [1, 0, 1, 1, 0, 1, 1, 0],
#  'conlangirl': [1, 1, 1, 0, 0, 0, 0, 0],
#  'BostonVic': [1, 0, 1, 0, 0, 0, 1, 0],
#  'DGTravelers': [1, 1, 1, 0, 0, 0, 0, 0],
#  'SoutheastSchatzi': [1, 1, 1, 1, 0, 0, 1, 0],
#  'whatawonderfulworld2': [1, 1, 1, 1, 1, 0, 1, 0],
#  'DeanPok': [1, 1, 1, 1, 0, 0, 1, 0],
#  'TexAZ': [1, 0, 1, 1, 0, 0, 1, 0],
#  'hrsllc': [1, 1, 1, 0, 0, 0, 0, 0],
#  'Sunshine118': [1, 1, 1, 1, 0, 1, 1, 0],
#  'NCFlyFisher25': [1, 1, 1, 1, 0, 1, 1, 0],
#  'MCMSuffolk': [1, 0, 1, 0, 0, 0, 0, 0],
#  'SigmaChiMatt': [1, 1, 0, 1, 0, 1, 1, 0],
#  'haha_no5': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Chacabuco': [1, 0, 1, 1, 0, 1, 0, 0],
#  'kencimino': [0, 0, 0, 1, 0, 1, 0, 0],
#  'TheBJWay': [1, 1, 1, 0, 0, 0, 0, 0],
#  'Bay': [0, 0, 1, 1, 0, 1, 1, 0],
#  'aaannarbor': [1, 1, 1, 1, 0, 0, 1, 0],
#  'KM70': [1, 0, 1, 0, 0, 1, 1, 0],
#  'annetpshop': [0, 0, 1, 1, 0, 1, 1, 0],
#  'DrDerm': [1, 1, 1, 1, 0, 0, 1, 1],
#  'PhiladelphiaWoman': [1, 0, 1, 1, 0, 1, 1, 0],
#  'gobled': [0, 0, 1, 1, 0, 0, 1, 0],
#  'jrockelein': [1, 1, 1, 0, 0, 1, 1, 0],
#  'legalgirl81': [1, 0, 1, 1, 0, 1, 1, 1],
#  'bveret': [1, 1, 1, 1, 0, 0, 0, 0],
#  'dougduey': [1, 1, 0, 1, 0, 1, 1, 0],
#  'Ronathon': [1, 1, 1, 1, 0, 1, 1, 0],
#  'bigdeal': [1, 0, 0, 1, 0, 0, 1, 0],
#  'LuvToTravel': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Ed_S_2004': [1, 1, 1, 1, 0, 1, 1, 0],
#  'TJGirl7': [1, 0, 1, 1, 0, 1, 1, 0],
#  'UkJenny': [1, 0, 1, 1, 0, 1, 1, 0],
#  'julie-wisk': [1, 1, 1, 1, 0, 0, 1, 0],
#  'seadawg_1999': [0, 0, 1, 1, 0, 0, 1, 0],
#  'Laderalady': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Brid1': [1, 1, 1, 1, 1, 1, 1, 0],
#  'Pegstrllite': [1, 0, 1, 1, 0, 1, 1, 0],
#  'annierlux': [1, 1, 1, 1, 0, 0, 1, 0],
#  'TexasGirlTravels': [1, 1, 1, 1, 1, 1, 1, 0],
#  'K_The_Tourist': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Katy&Fraser': [1, 1, 1, 0, 0, 1, 1, 0],
#  'onlyfirstclass': [1, 1, 1, 1, 1, 1, 1, 1],
#  'Plaiddream': [0, 1, 1, 1, 0, 1, 0, 0],
#  'Alfc': [1, 1, 1, 0, 0, 1, 1, 0],
#  'bmelter': [1, 1, 1, 1, 0, 0, 1, 1],
#  'tohhall': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Cucko': [1, 0, 1, 1, 0, 0, 1, 0],
#  '22traveler': [1, 1, 1, 0, 0, 0, 0, 0],
#  'pswemhoff': [1, 1, 1, 1, 1, 1, 1, 0],
#  'costabravahopeful': [1, 1, 1, 0, 0, 1, 0, 0],
#  'travelman11532': [1, 0, 1, 0, 0, 0, 1, 0],
#  'pm85': [1, 1, 1, 1, 1, 1, 1, 1],
#  'myhaven': [1, 1, 1, 1, 0, 1, 1, 0],
#  'dpowlan': [1, 1, 1, 1, 0, 0, 1, 0],
#  'ging1': [1, 1, 0, 1, 0, 0, 0, 0],
#  'ssolotraveler': [1, 0, 1, 0, 0, 1, 1, 0],
#  'c3g': [1, 0, 1, 1, 0, 1, 1, 0],
#  'chrisgene': [1, 1, 1, 0, 0, 1, 1, 1],
#  'Nolan64': [1, 1, 1, 1, 0, 1, 1, 0],
#  'glizzie': [1, 1, 1, 1, 0, 0, 1, 0],
#  'mjhill1004': [1, 1, 1, 1, 1, 1, 1, 1],
#  'Photopedia': [1, 1, 1, 1, 0, 0, 1, 0],
#  'FindMeAnOcean': [1, 1, 1, 1, 0, 0, 1, 0],
#  'V Traveler': [1, 1, 1, 1, 0, 1, 1, 1],
#  'jcraven23': [1, 1, 1, 1, 0, 1, 1, 0],
#  'PHiLMS': [0, 0, 0, 0, 0, 0, 1, 0],
#  'kferg99': [1, 0, 1, 1, 1, 1, 1, 0],
#  'stropertre': [1, 1, 1, 1, 0, 1, 1, 0],
#  'reneea': [1, 0, 1, 1, 0, 1, 1, 0],
#  'ChotaLancasterPA': [1, 0, 1, 1, 0, 0, 1, 0],
#  'jap86': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Atene': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Skipper39': [1, 1, 1, 1, 0, 1, 1, 0],
#  'KareBear': [1, 1, 1, 1, 1, 1, 1, 0],
#  'MMD007': [1, 0, 1, 1, 0, 0, 1, 0],
#  'ragout': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Maury5454': [0, 1, 1, 1, 0, 0, 1, 0],
#  'pickytravelmom': [1, 1, 1, 1, 0, 0, 1, 1],
#  'ltgnd': [1, 1, 1, 1, 0, 1, 1, 0],
#  'travellinghopefully': [1, 1, 1, 1, 0, 1, 1, 0],
#  'aksnorth': [1, 0, 1, 1, 0, 0, 1, 0],
#  'dtjan': [0, 1, 1, 0, 0, 0, 1, 1],
#  'ManilaPeasant': [1, 0, 0, 0, 0, 0, 0, 0],
#  'Lucy_Jones': [1, 1, 1, 1, 1, 1, 1, 0],
#  'suecumbria2': [1, 0, 1, 1, 0, 1, 0, 0],
#  'iaru': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Enjoys_Relaxing': [1, 1, 1, 1, 0, 1, 1, 0],
#  'oldalfer': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Willem_ter_Haar': [1, 0, 1, 1, 0, 0, 0, 0],
#  'fickleWestMids': [1, 1, 1, 0, 0, 0, 0, 0],
#  'Fitzy2': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Leothescouser': [1, 0, 1, 0, 0, 0, 1, 0],
#  'spec08': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Martyn_Megan': [1, 1, 0, 1, 0, 0, 1, 1],
#  'oldpapi': [1, 1, 1, 1, 0, 0, 1, 0],
#  'BarneyGrimsby_UK': [1, 1, 1, 1, 1, 1, 1, 1],
#  'popvoid': [1, 1, 1, 1, 0, 1, 1, 1],
#  'adventures4me': [1, 0, 1, 0, 0, 1, 1, 1],
#  'Owskie': [1, 1, 1, 0, 0, 1, 1, 0],
#  'gypsy71': [1, 1, 1, 0, 0, 1, 1, 0],
#  'michelle1986': [1, 0, 1, 0, 0, 0, 0, 1],
#  'Walklates world wide whims': [1, 1, 1, 1, 0, 1, 1, 1],
#  'christel': [1, 0, 1, 1, 0, 0, 1, 0],
#  'travel-world-mom': [1, 1, 1, 1, 0, 1, 1, 1],
#  'ziggyboston': [1, 1, 0, 1, 0, 1, 1, 0],
#  'bailestil': [1, 0, 0, 1, 0, 1, 0, 0],
#  'dglambeth': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Asterope': [1, 1, 1, 1, 1, 1, 1, 1],
#  'Vraiebrune': [1, 1, 1, 0, 0, 0, 0, 0],
#  'mmurray17': [1, 1, 1, 1, 0, 0, 1, 1],
#  'Rylo': [0, 1, 1, 0, 0, 1, 0, 0],
#  'caristocrat': [1, 1, 1, 1, 1, 1, 1, 0],
#  'Jetdriver21': [1, 1, 1, 1, 0, 1, 1, 0],
#  'doc_M': [1, 1, 1, 1, 1, 1, 1, 1],
#  'travelxyz': [1, 1, 1, 1, 0, 1, 0, 0],
#  'ixion': [1, 1, 1, 1, 1, 1, 1, 0],
#  'danielkegel': [1, 1, 1, 1, 1, 1, 1, 0],
#  'happyHongKong': [0, 0, 1, 0, 0, 0, 0, 0],
#  'cheshirepen': [1, 1, 1, 1, 1, 1, 1, 0],
#  'walkingredrose': [1, 1, 1, 0, 0, 1, 1, 0],
#  'Brude': [1, 1, 1, 1, 0, 1, 1, 0],
#  'mattrLondon': [1, 1, 1, 1, 1, 1, 1, 0],
#  'orangeIreland': [1, 1, 1, 1, 0, 1, 1, 0],
#  'xlguide_dk': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Rosneath': [1, 1, 1, 0, 0, 1, 1, 0],
#  'Fi65': [1, 1, 1, 1, 0, 1, 1, 0],
#  'MaximillianAmsterdam': [1, 1, 1, 1, 0, 1, 1, 1],
#  'LondonFuzzyface': [1, 0, 1, 1, 0, 0, 1, 0],
#  'lucyville': [1, 0, 1, 1, 1, 0, 0, 0],
#  'Francescini': [1, 1, 1, 1, 0, 0, 0, 0],
#  'sfdiva22': [0, 1, 0, 0, 0, 0, 0, 0],
#  'Dfenz': [1, 1, 1, 1, 0, 1, 1, 1],
#  'BaltimoreFrancophile': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Matt-7': [1, 0, 1, 1, 0, 1, 0, 0],
#  'NewsboyBelfast': [1, 1, 1, 1, 0, 1, 1, 0],
#  'GeoDevon': [1, 1, 1, 1, 0, 0, 1, 0],
#  'DrTwitch': [1, 1, 1, 0, 0, 0, 0, 0],
#  'NoTentsHere': [1, 0, 1, 1, 1, 0, 0, 0],
#  'stafbulp': [0, 0, 1, 0, 0, 0, 0, 0],
#  'Eduardo-7': [1, 0, 1, 1, 0, 0, 0, 0],
#  'Ally1374': [1, 1, 1, 1, 0, 0, 1, 0],
#  'HT1': [1, 1, 1, 1, 1, 1, 1, 1],
#  'partyqueen': [1, 0, 1, 1, 0, 0, 1, 0],
#  'katokat': [1, 0, 1, 1, 1, 1, 1, 0],
#  'TheGuandos': [0, 1, 1, 0, 0, 1, 1, 0],
#  'll76': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Alli_D': [1, 0, 1, 1, 0, 1, 1, 0],
#  'michaelmelton1': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Ali83': [1, 0, 1, 1, 0, 1, 1, 0],
#  'clannscotia': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Duberto': [1, 1, 1, 1, 0, 1, 1, 0],
#  'haithgirl': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Bangkokexpat': [1, 1, 1, 1, 1, 1, 1, 1],
#  'UCSD': [1, 0, 1, 1, 0, 0, 1, 0],
#  'Glamourpuss-Tourer': [1, 0, 0, 1, 0, 0, 1, 0],
#  'Wandzia22': [1, 1, 1, 1, 0, 1, 0, 0],
#  'kobri': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Promar': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Sim2406': [1, 1, 1, 1, 0, 1, 1, 0],
#  'imabari': [1, 1, 1, 1, 0, 1, 1, 0],
#  'lilJoJo': [0, 1, 1, 0, 0, 0, 0, 0],
#  'SFO-World-Traveller': [1, 1, 1, 1, 0, 1, 1, 0],
#  'EuroTravellerLDN': [0, 1, 1, 1, 1, 1, 1, 1],
#  'dpat17': [1, 0, 1, 1, 0, 1, 0, 0],
#  'arlu': [1, 1, 1, 1, 0, 1, 1, 0],
#  'pokemon': [1, 1, 1, 1, 1, 1, 0, 0],
#  'Olos': [0, 0, 1, 0, 0, 0, 0, 0],
#  'goldmbr': [1, 1, 1, 1, 0, 0, 0, 0],
#  'northerntravela': [1, 1, 0, 1, 0, 0, 1, 0],
#  'smoofy': [1, 1, 1, 1, 0, 1, 1, 0],
#  'carrotsarered': [1, 1, 1, 1, 1, 1, 1, 0],
#  'VidaLocaRanch': [1, 1, 1, 1, 1, 0, 1, 1],
#  'Bruno007': [1, 1, 1, 1, 0, 0, 1, 0],
#  'nina_auth': [0, 0, 0, 0, 0, 0, 1, 0],
#  'Cornishlaydee': [0, 1, 1, 1, 0, 1, 1, 0],
#  'daoboston': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Carson10': [1, 1, 1, 1, 0, 1, 1, 0],
#  'BerlinDrew': [1, 1, 1, 1, 0, 0, 1, 1],
#  'Biebi': [1, 0, 0, 1, 0, 0, 0, 0],
#  'dainabrisbane': [1, 1, 1, 1, 1, 1, 1, 0],
#  'sgeddie': [1, 1, 1, 1, 0, 1, 1, 0],
#  'eyewinker': [1, 1, 1, 1, 0, 0, 1, 1],
#  'Jampa40': [1, 1, 1, 1, 0, 1, 0, 0],
#  'ICRC1977': [1, 0, 1, 0, 0, 0, 1, 0],
#  'CamelClass': [1, 1, 1, 1, 0, 1, 1, 0],
#  'lbj2': [1, 1, 1, 1, 0, 0, 1, 0],
#  'TRJ': [1, 1, 1, 0, 0, 0, 1, 0],
#  'ma377': [1, 1, 1, 1, 0, 0, 0, 0],
#  'Veronica W': [0, 1, 0, 1, 0, 1, 1, 0],
#  'gonknoggin': [0, 0, 1, 0, 0, 0, 0, 0],
#  'screenname060309': [1, 0, 1, 1, 0, 0, 1, 0],
#  'gooner_cb21rf': [1, 1, 1, 1, 0, 1, 0, 1],
#  'rymat': [1, 0, 1, 1, 0, 0, 1, 0],
#  'Travandclair': [1, 1, 0, 1, 0, 0, 1, 0],
#  'coffeepot11': [0, 0, 1, 1, 0, 1, 1, 0],
#  'AB1': [1, 0, 0, 1, 1, 1, 1, 0],
#  'Gazing': [1, 0, 0, 1, 0, 0, 0, 0],
#  'smoothtalk': [1, 1, 1, 1, 0, 0, 1, 0],
#  'marcdocklands': [0, 1, 1, 1, 0, 0, 0, 0],
#  'IslandMaster': [1, 1, 1, 1, 0, 0, 0, 0],
#  'ynguy': [1, 1, 1, 1, 1, 1, 1, 1],
#  'wilburhertfordshire': [1, 0, 1, 0, 0, 0, 0, 0],
#  'Sharsco': [1, 1, 0, 1, 0, 1, 1, 0],
#  'EssexGriff': [1, 1, 0, 1, 0, 1, 1, 0],
#  'C3B': [1, 1, 1, 1, 0, 1, 1, 0],
#  'trenchchic': [1, 0, 1, 1, 0, 0, 0, 0],
#  'Winner_Wannabie': [1, 1, 0, 1, 0, 0, 1, 0],
#  'blissfultranquility': [0, 0, 1, 0, 0, 0, 0, 0],
#  'teachers_on_tour': [1, 1, 1, 1, 1, 1, 1, 1],
#  'John-Elaine': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Saroesque': [1, 0, 0, 1, 0, 0, 0, 0],
#  'Net1': [1, 1, 1, 1, 0, 1, 1, 0],
#  'a7ftt': [1, 1, 1, 1, 1, 1, 1, 1],
#  'Cyclist62': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Vickyj21': [1, 0, 1, 1, 0, 1, 0, 0],
#  'ozon': [1, 1, 1, 1, 1, 1, 1, 0],
#  'AM-Kent': [1, 1, 1, 0, 0, 0, 0, 0],
#  'LeoDublin': [1, 1, 1, 1, 0, 1, 1, 0],
#  'oldmastumpy': [0, 1, 1, 1, 0, 0, 1, 0],
#  'AllanKnaik': [1, 1, 1, 0, 0, 1, 0, 0],
#  'kiwitravelling': [1, 1, 1, 1, 0, 1, 1, 1],
#  'airedale_travellers': [1, 0, 1, 1, 0, 0, 0, 0],
#  'anubis1': [1, 1, 1, 0, 0, 0, 0, 0],
#  'Juan45': [1, 1, 1, 1, 1, 1, 1, 0],
#  'sarphil': [1, 0, 1, 1, 1, 1, 1, 0],
#  'carryall': [1, 0, 0, 1, 0, 0, 1, 0],
#  'Lotusgirl': [1, 0, 1, 1, 0, 0, 0, 0],
#  'trvljunky': [0, 1, 1, 1, 0, 0, 0, 0],
#  'Chris_54': [1, 1, 1, 1, 0, 1, 1, 1],
#  'TheGrimesReview': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Morgan&Sian': [0, 0, 0, 1, 1, 0, 1, 0],
#  'seantully': [1, 1, 1, 1, 0, 1, 1, 0],
#  'airedale1': [1, 1, 1, 0, 0, 1, 1, 0],
#  'NatsDad': [1, 1, 1, 1, 0, 0, 0, 0],
#  'Susan66': [1, 1, 1, 1, 0, 0, 1, 1],
#  'MrktMgr': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Happyhubby&Daddy': [1, 1, 1, 1, 1, 1, 1, 1],
#  'VA_Married_Couple': [1, 1, 1, 1, 1, 1, 0, 0],
#  'Paul_J_Anderson': [1, 1, 1, 0, 0, 1, 1, 0],
#  'mister.c.': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Himelda': [1, 1, 1, 1, 1, 1, 1, 0],
#  'joan-ed': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Chav69': [1, 1, 1, 1, 0, 1, 1, 0],
#  'hairdo': [1, 1, 0, 0, 0, 1, 1, 0],
#  'NKDEVLIN': [1, 1, 1, 1, 0, 0, 0, 0],
#  'ch9nem': [1, 1, 1, 0, 0, 1, 0, 0],
#  'StarMonkeys': [1, 0, 1, 0, 0, 1, 0, 0],
#  'mlip': [1, 1, 1, 1, 0, 1, 0, 1],
#  'OzBoy74': [1, 0, 1, 1, 0, 0, 1, 0],
#  'israelifamily': [1, 0, 1, 1, 1, 1, 1, 0],
#  'Parkin01': [1, 1, 1, 1, 0, 1, 1, 0],
#  'summers_slayer': [1, 1, 1, 1, 0, 1, 1, 0],
#  'member from': [1, 1, 0, 1, 0, 0, 1, 0],
#  'miramol': [1, 0, 1, 1, 1, 1, 1, 0],
#  'BuffDundee': [0, 0, 1, 0, 0, 1, 1, 0],
#  'natbro': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Clerkenwell': [1, 1, 1, 1, 1, 1, 1, 1],
#  'IrelandQwerty': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Englanderin': [1, 1, 1, 1, 0, 1, 1, 0],
#  'GlobeRoamer': [1, 1, 1, 1, 0, 1, 1, 1],
#  'SBCATraveler': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Edinburghtraveller': [1, 1, 1, 1, 0, 0, 1, 0],
#  'theboyb': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Eti': [1, 1, 1, 1, 0, 1, 1, 0],
#  'joshua-bwi': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Mil4d': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Joizee_HD': [1, 1, 1, 1, 0, 1, 1, 1],
#  'tschye': [0, 0, 0, 1, 0, 0, 0, 0],
#  'flinny': [1, 0, 1, 1, 0, 1, 1, 0],
#  'wllopez': [1, 1, 1, 1, 0, 1, 0, 0],
#  'KSergey': [1, 1, 1, 1, 0, 1, 1, 0],
#  'TraceyMcM': [1, 0, 1, 1, 1, 1, 1, 0],
#  'ricechrisb': [1, 1, 1, 1, 0, 0, 0, 0],
#  'bkfhol': [0, 0, 0, 1, 0, 1, 1, 0],
#  'Newcastleknowledge': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Lou78': [1, 1, 1, 1, 0, 1, 1, 0],
#  'DavidMooney': [1, 1, 1, 0, 0, 1, 0, 0],
#  'hxdirect': [1, 1, 1, 1, 0, 1, 1, 0],
#  'erniec': [1, 1, 1, 1, 0, 0, 1, 0],
#  'MikePrinceton': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Loulibelle': [1, 1, 1, 1, 1, 1, 1, 1],
#  'Cazwario': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Groncho': [1, 0, 1, 1, 1, 1, 0, 1],
#  'duke_clar': [1, 1, 1, 1, 1, 1, 1, 1],
#  'longmore': [1, 0, 1, 1, 0, 1, 1, 0],
#  'PhGAR': [1, 1, 1, 1, 0, 0, 0, 0],
#  'Portugal_Paul': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Bobgardiner': [1, 1, 1, 1, 0, 1, 1, 0],
#  'penguinsix': [1, 1, 1, 1, 1, 1, 1, 1],
#  'urbanguy1974': [0, 0, 0, 1, 0, 0, 1, 0],
#  'Delite7': [1, 1, 1, 1, 0, 1, 1, 0],
#  'lass=': [1, 1, 1, 1, 1, 1, 1, 1],
#  'HighFlyer2': [1, 1, 1, 1, 0, 1, 1, 1],
#  'icyoubaby': [1, 1, 1, 1, 0, 1, 1, 1],
#  'The Innocent Man': [1, 1, 1, 1, 0, 1, 1, 0],
#  'highfly': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Travelgnome': [1, 0, 1, 1, 0, 1, 1, 0],
#  'TravelBug128': [1, 1, 1, 1, 1, 1, 1, 1],
#  'emmessduesseldorf': [1, 1, 1, 1, 0, 1, 1, 1],
#  'susanjulia': [1, 1, 1, 1, 1, 1, 1, 0],
#  'ddoran': [1, 1, 1, 1, 0, 1, 1, 0],
#  'miss_smith': [1, 0, 1, 1, 1, 1, 1, 0],
#  'Angela089': [1, 1, 1, 1, 1, 0, 1, 0],
#  'eskimo': [1, 0, 1, 1, 0, 1, 1, 1],
#  'nikzik': [1, 0, 1, 0, 1, 1, 0, 0],
#  'rabatabar': [1, 1, 1, 1, 1, 1, 1, 0],
#  'DGlass': [1, 1, 1, 0, 0, 0, 0, 0],
#  'Jaws8': [1, 1, 1, 1, 0, 0, 0, 0],
#  'TanDublin_Ireland': [1, 1, 1, 0, 0, 1, 1, 1],
#  'ladywesson': [1, 1, 1, 1, 1, 1, 1, 0],
#  'thingummyjig': [1, 1, 1, 1, 0, 1, 1, 0],
#  'dtoe5': [1, 1, 1, 0, 1, 0, 1, 0],
#  'spacekid': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Readeverynight': [1, 1, 1, 1, 0, 0, 1, 1],
#  'CanberraSightseeker': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Holly13': [1, 0, 1, 1, 0, 0, 1, 0],
#  'alice87': [1, 0, 0, 0, 0, 0, 1, 0],
#  'gueray': [1, 1, 1, 1, 0, 1, 1, 0],
#  'sigmund': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Orric': [0, 1, 1, 0, 0, 0, 0, 0],
#  'cortile': [0, 1, 1, 0, 0, 1, 1, 0],
#  'nickwhite26': [1, 1, 1, 1, 0, 0, 0, 0],
#  'shonagon': [1, 0, 1, 1, 0, 1, 1, 0],
#  'mcmdee': [1, 1, 1, 1, 0, 0, 0, 0],
#  'Olderbytheday': [0, 0, 1, 0, 0, 0, 0, 0],
#  'sunshines': [0, 1, 1, 0, 0, 0, 1, 0],
#  'Zurich': [1, 1, 1, 1, 1, 1, 1, 1],
#  'LindaNZ': [1, 1, 1, 1, 0, 1, 1, 1],
#  'gaweca': [1, 1, 1, 1, 0, 1, 1, 0],
#  'sb_2004': [0, 1, 1, 1, 0, 0, 0, 0],
#  'HotelGourmand': [1, 1, 1, 0, 1, 1, 0, 0],
#  'csulbxx': [1, 1, 1, 1, 0, 0, 1, 0],
#  'iamscoby': [1, 1, 0, 1, 0, 1, 1, 0],
#  'arabguy': [0, 1, 1, 1, 0, 1, 1, 0],
#  'JChused': [0, 1, 1, 0, 0, 1, 1, 0],
#  'Peacheypc_123': [1, 1, 1, 1, 0, 1, 0, 0],
#  'changabella': [1, 1, 1, 1, 0, 1, 1, 0],
#  'ps12': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Sue020': [1, 0, 1, 1, 0, 0, 1, 1],
#  'Peirot': [0, 0, 0, 1, 0, 0, 0, 0],
#  'Linchen2511': [1, 0, 0, 0, 0, 0, 0, 0],
#  'druisiana': [1, 0, 0, 0, 0, 0, 0, 0],
#  'creditcrunch': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Traveler555555': [1, 1, 0, 1, 0, 0, 0, 0],
#  'ZacharyS': [1, 1, 1, 1, 0, 0, 0, 0],
#  'MoCaribfan': [1, 0, 0, 1, 0, 0, 0, 0],
#  'brownsWestYorkshire': [1, 0, 1, 1, 0, 0, 1, 0],
#  'proudftd': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Aroadtripper': [1, 1, 1, 1, 0, 1, 1, 0],
#  'lambertbunch': [1, 1, 1, 0, 1, 1, 1, 1],
#  'floridatraveldad': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Ba11istic': [1, 1, 1, 1, 0, 1, 0, 0],
#  'AuntieAnne22': [1, 1, 1, 1, 0, 1, 1, 0],
#  'B_Pope': [1, 1, 1, 1, 1, 1, 1, 0],
#  'flylikean': [1, 0, 1, 1, 0, 0, 1, 0],
#  'Mimiannb': [1, 0, 1, 1, 0, 0, 1, 0],
#  'SusanAtlanta': [1, 0, 1, 1, 0, 1, 1, 1],
#  'sightsnsounds': [1, 0, 1, 1, 0, 0, 1, 1],
#  'T_Loves_to_Travel': [1, 1, 1, 1, 0, 0, 1, 0],
#  'weezee42': [0, 0, 1, 1, 0, 0, 0, 0],
#  'vinson7': [1, 1, 1, 1, 0, 0, 1, 0],
#  'LoveTravel': [1, 0, 1, 1, 0, 1, 0, 0],
#  'finschick': [1, 0, 0, 1, 0, 0, 1, 0],
#  'ms2112': [1, 1, 1, 1, 1, 0, 1, 0],
#  'Assenzio': [1, 1, 0, 1, 0, 1, 1, 0],
#  'docbfree': [1, 1, 1, 1, 1, 0, 1, 0],
#  'howden': [1, 1, 1, 1, 0, 0, 0, 0],
#  'FLYDL': [1, 0, 0, 1, 0, 0, 0, 0],
#  'DrGeorge': [1, 0, 1, 1, 0, 1, 1, 0],
#  'gmkinhawaii': [0, 1, 1, 1, 0, 0, 0, 0],
#  'CBlazek': [0, 1, 1, 1, 0, 1, 1, 0],
#  'Printman2000': [1, 1, 1, 1, 0, 0, 0, 0],
#  'letstravel52': [1, 0, 1, 1, 0, 1, 1, 0],
#  'nieto': [1, 1, 0, 1, 0, 1, 1, 0],
#  'apswen': [0, 0, 1, 0, 0, 0, 0, 0],
#  'lisahaha': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Motherosh': [0, 1, 0, 1, 1, 0, 1, 0],
#  'WanderingWomanTN': [0, 0, 0, 0, 0, 0, 1, 0],
#  'Stella': [1, 1, 1, 1, 1, 1, 1, 1],
#  'perpendxular78': [1, 1, 1, 1, 1, 0, 0, 0],
#  'deeddog': [1, 1, 1, 1, 0, 1, 0, 0],
#  'daddy3x': [1, 0, 1, 1, 0, 0, 0, 0],
#  'albertatraveler2129': [1, 0, 1, 1, 0, 1, 1, 0],
#  'GandalfasWell': [1, 1, 0, 1, 0, 0, 1, 0],
#  'usalovers': [1, 0, 1, 1, 0, 0, 1, 0],
#  'lozmow': [1, 1, 1, 1, 0, 1, 1, 0],
#  'sprtplt': [1, 1, 1, 1, 0, 0, 1, 0],
#  'LakersFan': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Eric95403': [1, 1, 1, 1, 0, 0, 1, 0],
#  'CATim': [1, 0, 1, 1, 0, 1, 0, 0],
#  'cinncitraveler': [1, 1, 1, 1, 0, 1, 1, 1],
#  'AliceRochester_NY': [1, 0, 1, 1, 0, 0, 0, 0],
#  'millerswen': [1, 0, 0, 0, 0, 0, 0, 0],
#  'tishNchris': [0, 1, 1, 1, 0, 0, 1, 0],
#  'laflute': [1, 0, 1, 0, 0, 0, 0, 0],
#  'Andrewnn': [0, 1, 0, 0, 0, 0, 0, 0],
#  'TravelBug037': [1, 0, 1, 1, 0, 1, 1, 0],
#  'bobo41': [1, 0, 1, 1, 0, 0, 1, 0],
#  'trininlondon': [0, 0, 1, 0, 0, 0, 0, 0],
#  'LTRCalifornia': [1, 0, 0, 1, 0, 0, 0, 0],
#  'CerritosTotomom': [0, 0, 0, 1, 0, 1, 0, 0],
#  'Christinaribena': [1, 0, 1, 1, 0, 1, 1, 0],
#  'TwinkleSlater': [1, 0, 1, 1, 0, 1, 0, 0],
#  'Lindy011': [1, 0, 1, 1, 0, 1, 1, 0],
#  'eleuthra': [0, 1, 1, 0, 0, 0, 0, 0],
#  'notworldtraveller': [1, 0, 1, 1, 0, 1, 1, 0],
#  'augcar': [0, 0, 0, 1, 0, 0, 1, 0],
#  'Hannahanna': [0, 0, 1, 1, 0, 1, 1, 0],
#  'chance495': [1, 1, 1, 0, 1, 1, 0, 0],
#  'windsurfer_2003': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Reddave': [1, 1, 0, 0, 0, 0, 1, 0],
#  'pmac boston': [1, 0, 1, 1, 0, 1, 1, 0],
#  'JulezLondon': [1, 1, 1, 1, 0, 0, 0, 0],
#  'mcyclebabe': [0, 0, 1, 0, 0, 0, 0, 0],
#  'Ramon_y_Cajal': [1, 1, 1, 1, 1, 1, 1, 1],
#  'AttractiveYoungPair': [1, 1, 1, 1, 0, 1, 1, 0],
#  'DBMac': [0, 0, 1, 0, 0, 0, 0, 0],
#  'spec': [0, 1, 1, 0, 0, 1, 0, 0],
#  'vonschwind': [1, 1, 1, 1, 0, 1, 1, 1],
#  'M_and_JHouston': [1, 1, 1, 0, 0, 1, 1, 0],
#  'TheBigJ': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Marcia_Teles': [1, 0, 1, 0, 0, 0, 0, 0],
#  'CharAT': [0, 0, 0, 0, 0, 0, 0, 0],
#  'Tonguetwister': [1, 1, 1, 1, 0, 1, 1, 0],
#  'keenvisitor': [1, 1, 1, 0, 1, 0, 0, 0],
#  'brianhh': [1, 1, 1, 1, 0, 1, 1, 0],
#  'amer-ital': [1, 0, 1, 1, 0, 0, 0, 0],
#  'Stonetraveller': [0, 0, 1, 1, 0, 0, 1, 0],
#  'nicoler': [0, 1, 1, 1, 0, 1, 1, 0],
#  'kevinsf': [1, 0, 1, 1, 0, 0, 0, 0],
#  'TheFriedmans': [1, 0, 1, 1, 0, 1, 1, 0],
#  'malysa': [1, 0, 1, 1, 1, 1, 0, 0],
#  'mem2699': [1, 1, 1, 1, 1, 0, 1, 0],
#  'TAHull': [0, 1, 1, 1, 0, 0, 0, 0],
#  'Lucage66': [0, 1, 1, 1, 0, 1, 0, 0],
#  'cliffwy': [1, 0, 1, 1, 1, 1, 1, 0],
#  'archive': [0, 0, 1, 1, 0, 1, 1, 0],
#  'fashion_teacher99': [1, 0, 1, 0, 0, 1, 0, 0],
#  'churchmouse': [0, 1, 1, 0, 0, 1, 0, 0],
#  'emforster': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Curveball2': [0, 1, 1, 1, 0, 1, 1, 0],
#  'lelanni': [0, 0, 1, 0, 0, 0, 1, 0],
#  'dreampod21': [1, 0, 1, 0, 0, 1, 1, 0],
#  'Julianna22': [1, 0, 1, 1, 0, 1, 1, 0],
#  'traveler1239': [1, 0, 1, 0, 0, 0, 0, 1],
#  'matarsakzendeh': [1, 1, 1, 1, 1, 1, 1, 1],
#  'TravelGuy236': [1, 1, 1, 1, 0, 0, 0, 0],
#  'vgchao': [1, 1, 1, 1, 0, 1, 1, 1],
#  'CoronaBoy': [1, 1, 1, 1, 1, 1, 1, 0],
#  'Junipers': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Lilpixielaura': [1, 1, 1, 1, 1, 1, 1, 0],
#  'marina78_k': [1, 1, 1, 0, 0, 0, 0, 0],
#  'jonathanjo': [1, 1, 1, 0, 0, 0, 0, 0],
#  'DawsonUK': [1, 1, 1, 1, 0, 1, 1, 0],
#  'worldtraveler81': [1, 0, 1, 1, 0, 1, 1, 0],
#  'asdf5607': [1, 1, 1, 1, 0, 1, 0, 1],
#  'Londinium69': [1, 1, 1, 0, 1, 1, 0, 0],
#  'jfbrown55': [1, 1, 1, 1, 0, 1, 1, 0],
#  'M747': [1, 1, 1, 1, 0, 1, 1, 0],
#  'GlasgowNamron': [1, 1, 1, 0, 0, 1, 0, 0],
#  'zeketheportie': [1, 1, 1, 1, 0, 1, 1, 0],
#  'LeepyLoo': [1, 0, 1, 1, 0, 1, 1, 0],
#  'brgkamp': [0, 0, 1, 1, 0, 0, 1, 0],
#  'moonbaby9': [1, 1, 1, 1, 0, 1, 1, 0],
#  'johnTW16': [1, 1, 1, 1, 1, 1, 1, 0],
#  'name_screen': [1, 1, 1, 1, 1, 1, 1, 1],
#  'dotcom': [1, 1, 1, 1, 0, 1, 0, 1],
#  'ATLtraveler': [1, 0, 1, 1, 0, 0, 1, 0],
#  'Voyageur510': [1, 1, 1, 1, 1, 1, 1, 1],
#  'TA_MikeW': [1, 1, 1, 1, 0, 0, 1, 1],
#  'PattiMerritt': [1, 1, 1, 0, 0, 1, 1, 0],
#  'TopDMC': [0, 0, 0, 1, 0, 1, 0, 0],
#  'dantravellerman': [1, 1, 1, 0, 0, 0, 1, 0],
#  'Cashew07': [1, 1, 1, 1, 0, 0, 0, 0],
#  'PedroTheTripper': [1, 1, 1, 0, 0, 1, 0, 0],
#  'Swindoneric': [1, 1, 1, 0, 0, 1, 1, 0],
#  'nickymLondon': [1, 1, 1, 0, 0, 1, 1, 0],
#  'leasamarie': [1, 1, 0, 0, 0, 1, 1, 0],
#  'cdav25': [0, 0, 1, 0, 0, 0, 0, 0],
#  'Jazmincleo': [1, 1, 1, 1, 1, 1, 1, 1],
#  'AmsterdamerUk': [1, 1, 0, 1, 0, 0, 0, 0],
#  'Lara&Paul': [1, 1, 1, 1, 0, 1, 1, 0],
#  'Tartullian': [1, 1, 1, 1, 1, 0, 1, 0],
#  'LazyDave': [1, 1, 1, 1, 0, 1, 1, 0],
#  'TravelfromWisconsin': [1, 0, 1, 1, 0, 1, 0, 0],
#  'RedSavage': [0, 0, 1, 1, 0, 1, 1, 0],
#  'cibogirl': [0, 1, 1, 1, 0, 0, 0, 0],
#  'houl': [1, 1, 1, 1, 0, 1, 1, 0],
#  'TallCool1': [1, 1, 1, 1, 0, 0, 0, 0],
#  'bbigdaddy': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Scotslads': [0, 0, 1, 0, 0, 0, 0, 0],
#  'crossVancouver_BC': [1, 0, 1, 1, 1, 1, 1, 0],
#  'racinrags': [1, 0, 1, 0, 0, 1, 0, 0],
#  'advum': [1, 0, 1, 1, 0, 1, 1, 0],
#  'ted1690': [1, 0, 1, 1, 0, 0, 1, 0],
#  'KPeirce': [1, 1, 1, 0, 0, 1, 0, 0],
#  'jtriefen': [1, 1, 1, 1, 0, 0, 0, 0],
#  'Rebbew': [1, 1, 1, 1, 1, 1, 1, 0],
#  'skyewalker16': [1, 1, 1, 1, 0, 1, 1, 0],
#  'bjorkman': [1, 1, 1, 1, 0, 0, 1, 0],
#  'SailingTheWorld': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Travel4Lving': [1, 1, 1, 1, 0, 1, 1, 0],
#  'isaacmeirn': [1, 1, 1, 0, 0, 1, 1, 1],
#  'Digicision': [0, 1, 0, 1, 0, 0, 0, 0],
#  'worldClassTraveler7': [0, 1, 1, 1, 0, 1, 0, 0],
#  'blackszabbi': [1, 1, 1, 1, 0, 1, 1, 1],
#  'angelee': [1, 0, 1, 1, 0, 0, 1, 0],
#  'lindy1991': [1, 1, 1, 1, 0, 1, 1, 0],
#  'cha630': [1, 0, 1, 1, 0, 0, 1, 0],
#  'smokemon': [1, 1, 1, 1, 0, 0, 1, 0],
#  'caseyk1984': [1, 1, 1, 1, 0, 1, 1, 0],
#  'huntermvs': [1, 0, 1, 1, 0, 1, 1, 0],
#  'gemmauk': [1, 1, 1, 1, 0, 1, 1, 0],
#  'petrol1967': [1, 1, 1, 1, 1, 1, 1, 0],
#  'Barry,London': [0, 1, 1, 1, 0, 1, 1, 0],
#  'raavani': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Szymon-Luxembourg': [1, 1, 1, 0, 0, 0, 1, 0],
#  'Sez2802': [1, 1, 1, 1, 0, 1, 0, 0],
#  'Liat': [1, 0, 1, 1, 0, 1, 1, 0],
#  'Bintang': [1, 1, 1, 1, 0, 1, 1, 0],
#  'GaryHLondon': [1, 1, 1, 1, 0, 1, 1, 0],
#  'melyte': [1, 0, 1, 1, 1, 1, 0, 0],
#  'Parris': [1, 0, 1, 1, 1, 1, 1, 0],
#  'pamnrobnemnernel': [1, 0, 1, 1, 1, 1, 1, 0],
#  'Febo17': [1, 1, 1, 1, 1, 1, 1, 1],
#  'AP_Phoenix': [1, 1, 1, 1, 0, 1, 1, 1],
#  'webtrainer': [1, 1, 0, 1, 0, 0, 0, 0],
#  'mandylawson': [1, 0, 1, 0, 0, 1, 1, 0],
#  'SelenaBartlett': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Ex-smoker': [1, 0, 0, 1, 1, 0, 1, 0],
#  'KingDoody': [1, 1, 1, 1, 0, 0, 1, 1],
#  'suz_mitchell': [1, 1, 0, 0, 0, 1, 0, 0],
#  'allenweiner': [1, 1, 1, 1, 1, 1, 1, 0],
#  'saskatoonguy': [1, 1, 1, 1, 0, 1, 1, 0],
#  'andrewclauer': [1, 1, 1, 1, 1, 1, 1, 1],
#  'burgo1804': [1, 1, 1, 1, 0, 0, 1, 0],
#  'Roy A M': [1, 1, 1, 1, 0, 0, 0, 0],
#  'ange70': [0, 1, 0, 0, 0, 0, 0, 0],
#  'rsh1625': [1, 1, 1, 1, 0, 1, 0, 0],
#  'mkc87': [0, 1, 1, 1, 0, 0, 0, 0],
#  'Noldesh': [1, 1, 0, 0, 0, 1, 1, 0],
#  'alexb2': [1, 1, 1, 1, 0, 0, 1, 0],
#  'abece': [0, 1, 1, 1, 0, 1, 0, 0],
#  'roberee': [1, 1, 1, 1, 0, 1, 1, 1],
#  'Sacman': [1, 0, 1, 1, 0, 0, 1, 1],
#  ...}
